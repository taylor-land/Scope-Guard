# %% [markdown]
# <a href="https://colab.research.google.com/github/taylor-land/Scope-Guard/blob/main/ScopeGuardDatasetCreation006ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import random
import copy
import pandas as pd

# %%
#Setting random seed hyper param:
RANDOM_SEED = 42

# %%
with open('/content/google_oauth_scope_catalog.json', 'r') as file:
    data = json.load(file)

# %%
for item in data:
  print(item)
# Out:
# metadata
# services_summary
# scopes

# %%
scopes = data['scopes']

# %%
for scope in scopes:
  print(scope)
# Out:
# {'scope': 'https://mail.google.com/', 'api': 'Gmail API', 'api_version': 'v1', 'description': 'Read, compose, send, and permanently delete all your email from Gmail', 'service': 'Gmail', 'access_type': 'full_access', 'google_classification': 'restricted'}
# {'scope': 'https://www.googleapis.com/auth/gmail.addons.current.action.compose', 'api': 'Gmail API', 'api_version': 'v1', 'description': 'Manage drafts and send emails when you interact with the add-on', 'service': 'Gmail', 'access_type': 'write', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/gmail.addons.current.message.action', 'api': 'Gmail API', 'api_version': 'v1', 'description': 'View your email messages when you interact with the add-on', 'service': 'Gmail', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/gmail.addons.current.message.metadata', 'api': 'Gmail API', 'api_version': 'v1', 'description': 'View your email message metadata when the add-on is running', 'service': 'Gmail', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/gmail.addons.current.message.readonly', 'api': 'Gmail API', 'api_version': 'v1', 'description': 'View your email messages when the add-on is running', 'service': 'Gmail', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/gmail.compose', 'api': 'Gmail API', 'api_version': 'v1', 'description': 'Manage drafts and send emails', 'service': 'Gmail', 'access_type': 'write', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/gmail.insert', 'api': 'Gmail API', 'api_version': 'v1', 'description': 'Add emails into your Gmail mailbox', 'service': 'Gmail', 'access_type': 'write', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/gmail.labels', 'api': 'Gmail API', 'api_version': 'v1', 'description': 'See and edit your email labels', 'service': 'Gmail', 'access_type': 'read_write', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/gmail.metadata', 'api': 'Gmail API', 'api_version': 'v1', 'description': 'View your email message metadata such as labels and headers, but not the email body', 'service': 'Gmail', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/gmail.modify', 'api': 'Gmail API', 'api_version': 'v1', 'description': 'Read, compose, and send emails from your Gmail account', 'service': 'Gmail', 'access_type': 'read_write', 'google_classification': 'restricted'}
# {'scope': 'https://www.googleapis.com/auth/gmail.readonly', 'api': 'Gmail API', 'api_version': 'v1', 'description': 'View your email messages and settings', 'service': 'Gmail', 'access_type': 'read', 'google_classification': 'restricted'}
# {'scope': 'https://www.googleapis.com/auth/gmail.send', 'api': 'Gmail API', 'api_version': 'v1', 'description': 'Send email on your behalf', 'service': 'Gmail', 'access_type': 'write', 'google_classification': 'restricted'}
# {'scope': 'https://www.googleapis.com/auth/gmail.settings.basic', 'api': 'Gmail API', 'api_version': 'v1', 'description': 'See, edit, create, or change your email settings and filters in Gmail', 'service': 'Gmail', 'access_type': 'read_write', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/gmail.settings.sharing', 'api': 'Gmail API', 'api_version': 'v1', 'description': 'Manage your sensitive mail settings, including who can manage your mail', 'service': 'Gmail', 'access_type': 'write', 'google_classification': 'restricted'}
# {'scope': 'https://www.googleapis.com/auth/drive', 'api': 'Google Drive API', 'api_version': 'v3', 'description': 'See, edit, create, and delete all of your Google Drive files', 'service': 'Drive', 'access_type': 'full_access', 'google_classification': 'restricted'}
# {'scope': 'https://www.googleapis.com/auth/drive.appdata', 'api': 'Google Drive API', 'api_version': 'v3', 'description': 'See, create, and delete its own configuration data in your Google Drive', 'service': 'Drive', 'access_type': 'read_write', 'google_classification': 'non_sensitive'}
# {'scope': 'https://www.googleapis.com/auth/drive.file', 'api': 'Google Drive API', 'api_version': 'v3', 'description': 'See, edit, create, and delete only the specific Google Drive files you use with this app', 'service': 'Drive', 'access_type': 'read_write', 'google_classification': 'non_sensitive'}
# {'scope': 'https://www.googleapis.com/auth/drive.metadata', 'api': 'Google Drive API', 'api_version': 'v3', 'description': 'View and manage metadata of files in your Google Drive', 'service': 'Drive', 'access_type': 'read_write', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/drive.metadata.readonly', 'api': 'Google Drive API', 'api_version': 'v3', 'description': 'See information about your Google Drive files', 'service': 'Drive', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/drive.photos.readonly', 'api': 'Google Drive API', 'api_version': 'v3', 'description': 'View the photos, videos and albums in your Google Photos', 'service': 'Drive', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/drive.readonly', 'api': 'Google Drive API', 'api_version': 'v3', 'description': 'See and download all your Google Drive files', 'service': 'Drive', 'access_type': 'read', 'google_classification': 'restricted'}
# {'scope': 'https://www.googleapis.com/auth/drive.scripts', 'api': 'Google Drive API', 'api_version': 'v3', 'description': "Modify your Google Apps Script scripts' behavior", 'service': 'Drive', 'access_type': 'write', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/drive.activity', 'api': 'Drive Activity API', 'api_version': 'v2', 'description': 'View and add to the activity record of files in your Google Drive', 'service': 'Drive', 'access_type': 'read_write', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/drive.activity.readonly', 'api': 'Drive Activity API', 'api_version': 'v2', 'description': 'View the activity record of files in your Google Drive', 'service': 'Drive', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/calendar', 'api': 'Calendar API', 'api_version': 'v3', 'description': 'See, edit, share, and permanently delete all the calendars you can access using Google Calendar', 'service': 'Calendar', 'access_type': 'full_access', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/calendar.acls', 'api': 'Calendar API', 'api_version': 'v3', 'description': 'See and change the sharing permissions of Google calendars you own', 'service': 'Calendar', 'access_type': 'read_write', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/calendar.acls.readonly', 'api': 'Calendar API', 'api_version': 'v3', 'description': 'See the sharing permissions of Google calendars you own', 'service': 'Calendar', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/calendar.app.created', 'api': 'Calendar API', 'api_version': 'v3', 'description': 'Make secondary Google calendars, and see, create, change, and delete events on them', 'service': 'Calendar', 'access_type': 'read_write', 'google_classification': 'non_sensitive'}
# {'scope': 'https://www.googleapis.com/auth/calendar.calendarlist', 'api': 'Calendar API', 'api_version': 'v3', 'description': "See, add, and remove Google calendars you're subscribed to", 'service': 'Calendar', 'access_type': 'read_write', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/calendar.calendarlist.readonly', 'api': 'Calendar API', 'api_version': 'v3', 'description': "See the list of Google calendars you're subscribed to", 'service': 'Calendar', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/calendar.calendars', 'api': 'Calendar API', 'api_version': 'v3', 'description': 'See and change the properties of Google calendars you have access to, and create secondary calendars', 'service': 'Calendar', 'access_type': 'read_write', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/calendar.calendars.readonly', 'api': 'Calendar API', 'api_version': 'v3', 'description': 'See the title, description, default time zone, and other properties of Google calendars you have access to', 'service': 'Calendar', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/calendar.events', 'api': 'Calendar API', 'api_version': 'v3', 'description': 'View and edit events on all your calendars', 'service': 'Calendar', 'access_type': 'read_write', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/calendar.events.freebusy', 'api': 'Calendar API', 'api_version': 'v3', 'description': 'See the availability on Google calendars you have access to', 'service': 'Calendar', 'access_type': 'read', 'google_classification': 'non_sensitive'}
# {'scope': 'https://www.googleapis.com/auth/calendar.events.owned', 'api': 'Calendar API', 'api_version': 'v3', 'description': 'See, create, change, and delete events on Google calendars you own', 'service': 'Calendar', 'access_type': 'read_write', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/calendar.events.owned.readonly', 'api': 'Calendar API', 'api_version': 'v3', 'description': 'See the events on Google calendars you own', 'service': 'Calendar', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/calendar.events.public.readonly', 'api': 'Calendar API', 'api_version': 'v3', 'description': 'See the events on public calendars', 'service': 'Calendar', 'access_type': 'read', 'google_classification': 'non_sensitive'}
# {'scope': 'https://www.googleapis.com/auth/calendar.events.readonly', 'api': 'Calendar API', 'api_version': 'v3', 'description': 'View events on all your calendars', 'service': 'Calendar', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/calendar.freebusy', 'api': 'Calendar API', 'api_version': 'v3', 'description': 'View your availability in your calendars', 'service': 'Calendar', 'access_type': 'read', 'google_classification': 'non_sensitive'}
# {'scope': 'https://www.googleapis.com/auth/calendar.readonly', 'api': 'Calendar API', 'api_version': 'v3', 'description': 'See and download any calendar you can access using your Google Calendar', 'service': 'Calendar', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/calendar.settings.readonly', 'api': 'Calendar API', 'api_version': 'v3', 'description': 'View your Calendar settings', 'service': 'Calendar', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/contacts', 'api': 'People API', 'api_version': 'v1', 'description': 'See, edit, download, and permanently delete your contacts', 'service': 'Contacts', 'access_type': 'full_access', 'google_classification': 'restricted'}
# {'scope': 'https://www.googleapis.com/auth/contacts.readonly', 'api': 'People API', 'api_version': 'v1', 'description': 'See and download your contacts', 'service': 'Contacts', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/contacts.other.readonly', 'api': 'People API', 'api_version': 'v1', 'description': "See and download contact info automatically saved in your 'Other contacts'", 'service': 'Contacts', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/directory.readonly', 'api': 'People API', 'api_version': 'v1', 'description': "See and download your organization's GSuite directory", 'service': 'Contacts', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/user.addresses.read', 'api': 'People API', 'api_version': 'v1', 'description': 'View your street addresses', 'service': 'Contacts', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/user.birthday.read', 'api': 'People API', 'api_version': 'v1', 'description': 'See and download your exact date of birth', 'service': 'Contacts', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/user.emails.read', 'api': 'People API', 'api_version': 'v1', 'description': 'See and download all email addresses associated with your Google Account', 'service': 'Contacts', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/user.gender.read', 'api': 'People API', 'api_version': 'v1', 'description': 'See your gender', 'service': 'Contacts', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/user.organization.read', 'api': 'People API', 'api_version': 'v1', 'description': 'See your education, work history and org info', 'service': 'Contacts', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/user.phonenumbers.read', 'api': 'People API', 'api_version': 'v1', 'description': 'See and download your personal phone numbers', 'service': 'Contacts', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/userinfo.email', 'api': 'People API', 'api_version': 'v1', 'description': 'See your primary Google Account email address', 'service': 'Identity', 'access_type': 'read', 'google_classification': 'non_sensitive'}
# {'scope': 'https://www.googleapis.com/auth/userinfo.profile', 'api': 'People API', 'api_version': 'v1', 'description': "See your personal info, including any personal info you've made publicly available", 'service': 'Identity', 'access_type': 'read', 'google_classification': 'non_sensitive'}
# {'scope': 'openid', 'api': 'OpenID Connect', 'api_version': 'v1', 'description': 'Authenticate using OpenID Connect', 'service': 'Identity', 'access_type': 'read', 'google_classification': 'non_sensitive'}
# {'scope': 'profile', 'api': 'OpenID Connect', 'api_version': 'v1', 'description': 'View basic profile info', 'service': 'Identity', 'access_type': 'read', 'google_classification': 'non_sensitive'}
# {'scope': 'email', 'api': 'OpenID Connect', 'api_version': 'v1', 'description': 'View email address', 'service': 'Identity', 'access_type': 'read', 'google_classification': 'non_sensitive'}
# {'scope': 'https://www.googleapis.com/auth/documents', 'api': 'Google Docs API', 'api_version': 'v1', 'description': 'See, edit, create, and delete all your Google Docs documents', 'service': 'Docs', 'access_type': 'full_access', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/documents.readonly', 'api': 'Google Docs API', 'api_version': 'v1', 'description': 'See all your Google Docs documents', 'service': 'Docs', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/spreadsheets', 'api': 'Google Sheets API', 'api_version': 'v4', 'description': 'See, edit, create, and delete all your Google Sheets spreadsheets', 'service': 'Sheets', 'access_type': 'full_access', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/spreadsheets.readonly', 'api': 'Google Sheets API', 'api_version': 'v4', 'description': 'See all your Google Sheets spreadsheets', 'service': 'Sheets', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/presentations', 'api': 'Google Slides API', 'api_version': 'v1', 'description': 'See, edit, create, and delete all your Google Slides presentations', 'service': 'Slides', 'access_type': 'full_access', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/presentations.readonly', 'api': 'Google Slides API', 'api_version': 'v1', 'description': 'See all your Google Slides presentations', 'service': 'Slides', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/forms', 'api': 'Google Forms API', 'api_version': 'v1', 'description': 'View and manage your forms in Google Drive', 'service': 'Forms', 'access_type': 'read_write', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/forms.body', 'api': 'Google Forms API', 'api_version': 'v1', 'description': 'See, edit, create, and delete all of your Google Forms forms', 'service': 'Forms', 'access_type': 'full_access', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/forms.body.readonly', 'api': 'Google Forms API', 'api_version': 'v1', 'description': 'See all your Google Forms forms', 'service': 'Forms', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/forms.responses.readonly', 'api': 'Google Forms API', 'api_version': 'v1', 'description': 'See all responses to your Google Forms forms', 'service': 'Forms', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/forms.currentonly', 'api': 'Apps Script API', 'api_version': 'v1', 'description': 'View and manage forms that this application has been installed in', 'service': 'Forms', 'access_type': 'read_write', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/tasks', 'api': 'Google Tasks API', 'api_version': 'v1', 'description': 'Create, edit, organize, and delete all your tasks', 'service': 'Tasks', 'access_type': 'full_access', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/tasks.readonly', 'api': 'Google Tasks API', 'api_version': 'v1', 'description': 'View your tasks', 'service': 'Tasks', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/keep', 'api': 'Google Keep API', 'api_version': 'v1', 'description': 'See, edit, create, and permanently delete all your Google Keep data', 'service': 'Keep', 'access_type': 'full_access', 'google_classification': 'restricted'}
# {'scope': 'https://www.googleapis.com/auth/keep.readonly', 'api': 'Google Keep API', 'api_version': 'v1', 'description': 'View all your Google Keep data', 'service': 'Keep', 'access_type': 'read', 'google_classification': 'restricted'}
# {'scope': 'https://www.googleapis.com/auth/youtube', 'api': 'YouTube Data API', 'api_version': 'v3', 'description': 'Manage your YouTube account', 'service': 'YouTube', 'access_type': 'full_access', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/youtube.readonly', 'api': 'YouTube Data API', 'api_version': 'v3', 'description': 'View your YouTube account', 'service': 'YouTube', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/youtube.upload', 'api': 'YouTube Data API', 'api_version': 'v3', 'description': 'Manage your YouTube videos', 'service': 'YouTube', 'access_type': 'write', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/youtube.force-ssl', 'api': 'YouTube Data API', 'api_version': 'v3', 'description': 'See, edit, and permanently delete your YouTube videos, ratings, comments and captions', 'service': 'YouTube', 'access_type': 'full_access', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/youtubepartner', 'api': 'YouTube Data API', 'api_version': 'v3', 'description': 'View and manage your assets and associated content on YouTube', 'service': 'YouTube', 'access_type': 'full_access', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/fitness.activity.read', 'api': 'Fitness API', 'api_version': 'v1', 'description': 'Use Google Fit to see and store your physical activity data', 'service': 'Fitness', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/fitness.activity.write', 'api': 'Fitness API', 'api_version': 'v1', 'description': 'Add to your Google Fit physical activity data', 'service': 'Fitness', 'access_type': 'write', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/fitness.blood_glucose.read', 'api': 'Fitness API', 'api_version': 'v1', 'description': 'See info about your blood glucose in Google Fit', 'service': 'Fitness', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/fitness.blood_pressure.read', 'api': 'Fitness API', 'api_version': 'v1', 'description': 'See info about your blood pressure in Google Fit', 'service': 'Fitness', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/fitness.body.read', 'api': 'Fitness API', 'api_version': 'v1', 'description': 'See info about your body measurements in Google Fit', 'service': 'Fitness', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/fitness.heart_rate.read', 'api': 'Fitness API', 'api_version': 'v1', 'description': 'See your heart rate data in Google Fit', 'service': 'Fitness', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/fitness.location.read', 'api': 'Fitness API', 'api_version': 'v1', 'description': 'See your Google Fit speed and distance data', 'service': 'Fitness', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/fitness.sleep.read', 'api': 'Fitness API', 'api_version': 'v1', 'description': 'See your sleep data in Google Fit', 'service': 'Fitness', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/photoslibrary', 'api': 'Photos Library API', 'api_version': 'v1', 'description': 'View and manage your Google Photos library', 'service': 'Photos', 'access_type': 'full_access', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/photoslibrary.readonly', 'api': 'Photos Library API', 'api_version': 'v1', 'description': 'View your Google Photos library', 'service': 'Photos', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/photoslibrary.appendonly', 'api': 'Photos Library API', 'api_version': 'v1', 'description': 'Add to your Google Photos library', 'service': 'Photos', 'access_type': 'write', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/photoslibrary.readonly.appcreateddata', 'api': 'Photos Library API', 'api_version': 'v1', 'description': 'Manage photos added by this app', 'service': 'Photos', 'access_type': 'read', 'google_classification': 'non_sensitive'}
# {'scope': 'https://www.googleapis.com/auth/chat.messages', 'api': 'Google Chat API', 'api_version': 'v1', 'description': 'See, compose, send, update, and delete messages and their reactions', 'service': 'Chat', 'access_type': 'full_access', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/chat.messages.readonly', 'api': 'Google Chat API', 'api_version': 'v1', 'description': 'See messages and their reactions in Google Chat', 'service': 'Chat', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/chat.spaces', 'api': 'Google Chat API', 'api_version': 'v1', 'description': 'Create conversations and spaces and see or update metadata in Google Chat', 'service': 'Chat', 'access_type': 'read_write', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/chat.spaces.readonly', 'api': 'Google Chat API', 'api_version': 'v1', 'description': 'View chat and spaces in Google Chat', 'service': 'Chat', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/chat.memberships', 'api': 'Google Chat API', 'api_version': 'v1', 'description': 'See, add, update, and remove members from conversations and spaces in Google Chat', 'service': 'Chat', 'access_type': 'read_write', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/chat.delete', 'api': 'Google Chat API', 'api_version': 'v1', 'description': 'Delete conversations and spaces and remove access to associated files in Google Chat', 'service': 'Chat', 'access_type': 'write', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/script.projects', 'api': 'Apps Script API', 'api_version': 'v1', 'description': 'Create and update Google Apps Script projects', 'service': 'Apps Script', 'access_type': 'write', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/script.projects.readonly', 'api': 'Apps Script API', 'api_version': 'v1', 'description': 'View Google Apps Script projects', 'service': 'Apps Script', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/script.deployments', 'api': 'Apps Script API', 'api_version': 'v1', 'description': 'Create and update Google Apps Script deployments', 'service': 'Apps Script', 'access_type': 'write', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/admin.directory.user', 'api': 'Admin SDK API', 'api_version': 'v1', 'description': 'View and manage the provisioning of users on your domain', 'service': 'Admin', 'access_type': 'full_access', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/admin.directory.user.readonly', 'api': 'Admin SDK API', 'api_version': 'v1', 'description': 'See info about users on your domain', 'service': 'Admin', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/admin.directory.group', 'api': 'Admin SDK API', 'api_version': 'v1', 'description': 'View and manage the provisioning of groups on your domain', 'service': 'Admin', 'access_type': 'full_access', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/admin.directory.domain', 'api': 'Admin SDK API', 'api_version': 'v1', 'description': 'View and manage the provisioning of domains for your customers', 'service': 'Admin', 'access_type': 'full_access', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/admin.directory.user.security', 'api': 'Admin SDK API', 'api_version': 'v1', 'description': 'Manage data access permissions for users on your domain', 'service': 'Admin', 'access_type': 'write', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/admin.directory.rolemanagement', 'api': 'Admin SDK API', 'api_version': 'v1', 'description': 'Manage delegated admin roles for your domain', 'service': 'Admin', 'access_type': 'full_access', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/admin.reports.audit.readonly', 'api': 'Admin SDK API', 'api_version': 'v1', 'description': 'View audit reports for your Google Workspace domain', 'service': 'Admin', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/admin.datatransfer', 'api': 'Admin SDK API', 'api_version': 'v1', 'description': 'View and manage data transfers between users in your organization', 'service': 'Admin', 'access_type': 'read_write', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/cloud-platform', 'api': 'Cloud Platform', 'api_version': 'v1', 'description': 'See, edit, configure, and delete your Google Cloud data and see the email address for your Google Account', 'service': 'Cloud', 'access_type': 'full_access', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/cloud-platform.read-only', 'api': 'Cloud Platform', 'api_version': 'v1', 'description': 'View your data across Google Cloud services and see the email address of your Google Account', 'service': 'Cloud', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/devstorage.full_control', 'api': 'Cloud Storage JSON API', 'api_version': 'v1', 'description': 'Manage your data and permissions in Cloud Storage and see the email address for your Google Account', 'service': 'Cloud Storage', 'access_type': 'full_access', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/devstorage.read_only', 'api': 'Cloud Storage JSON API', 'api_version': 'v1', 'description': 'View your data in Google Cloud Storage', 'service': 'Cloud Storage', 'access_type': 'read', 'google_classification': 'non_sensitive'}
# {'scope': 'https://www.googleapis.com/auth/devstorage.read_write', 'api': 'Cloud Storage JSON API', 'api_version': 'v1', 'description': 'Manage your data in Cloud Storage and see the email address of your Google Account', 'service': 'Cloud Storage', 'access_type': 'read_write', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/bigquery', 'api': 'BigQuery API', 'api_version': 'v2', 'description': 'View and manage your data in Google BigQuery and see the email address for your Google Account', 'service': 'BigQuery', 'access_type': 'full_access', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/bigquery.insertdata', 'api': 'BigQuery API', 'api_version': 'v2', 'description': 'Insert data into Google BigQuery', 'service': 'BigQuery', 'access_type': 'write', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/compute', 'api': 'Compute Engine API', 'api_version': 'v1', 'description': 'View and manage your Google Compute Engine resources', 'service': 'Compute', 'access_type': 'full_access', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/compute.readonly', 'api': 'Compute Engine API', 'api_version': 'v1', 'description': 'View your Google Compute Engine resources', 'service': 'Compute', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/blogger', 'api': 'Blogger API', 'api_version': 'v3', 'description': 'Manage your Blogger account', 'service': 'Blogger', 'access_type': 'full_access', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/blogger.readonly', 'api': 'Blogger API', 'api_version': 'v3', 'description': 'View your Blogger account', 'service': 'Blogger', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/analytics', 'api': 'Google Analytics API', 'api_version': 'v3', 'description': 'View and manage your Google Analytics data', 'service': 'Analytics', 'access_type': 'full_access', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/analytics.readonly', 'api': 'Google Analytics API', 'api_version': 'v3', 'description': 'View your Google Analytics data', 'service': 'Analytics', 'access_type': 'read', 'google_classification': 'non_sensitive'}
# {'scope': 'https://www.googleapis.com/auth/analytics.edit', 'api': 'Google Analytics API', 'api_version': 'v3', 'description': 'Edit Google Analytics management entities', 'service': 'Analytics', 'access_type': 'write', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/analytics.manage.users', 'api': 'Google Analytics API', 'api_version': 'v3', 'description': 'Manage Google Analytics Account users by email address', 'service': 'Analytics', 'access_type': 'write', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/adsense', 'api': 'AdSense Management API', 'api_version': 'v2', 'description': 'View and manage your AdSense data', 'service': 'AdSense', 'access_type': 'full_access', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/adsense.readonly', 'api': 'AdSense Management API', 'api_version': 'v2', 'description': 'View your AdSense data', 'service': 'AdSense', 'access_type': 'read', 'google_classification': 'non_sensitive'}
# {'scope': 'https://www.googleapis.com/auth/groups', 'api': 'Apps Script API', 'api_version': 'v1', 'description': 'View and manage your Google Groups', 'service': 'Groups', 'access_type': 'full_access', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/firebase', 'api': 'Firebase Management API', 'api_version': 'v1beta1', 'description': 'View and administer all your Firebase data and settings', 'service': 'Firebase', 'access_type': 'full_access', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/firebase.readonly', 'api': 'Firebase Management API', 'api_version': 'v1beta1', 'description': 'View all your Firebase data and settings', 'service': 'Firebase', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/firebase.messaging', 'api': 'Firebase Cloud Messaging API', 'api_version': 'v1', 'description': 'Send messages and manage messaging subscriptions for your Firebase applications', 'service': 'Firebase', 'access_type': 'write', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/classroom.courses', 'api': 'Classroom API', 'api_version': 'v1', 'description': 'See, edit, create, and delete your Google Classroom classes', 'service': 'Classroom', 'access_type': 'full_access', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/classroom.courses.readonly', 'api': 'Classroom API', 'api_version': 'v1', 'description': 'View your Google Classroom classes', 'service': 'Classroom', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/classroom.rosters', 'api': 'Classroom API', 'api_version': 'v1', 'description': 'Manage your Google Classroom class rosters', 'service': 'Classroom', 'access_type': 'read_write', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/classroom.profile.emails', 'api': 'Classroom API', 'api_version': 'v1', 'description': 'View the email addresses of people in your classes', 'service': 'Classroom', 'access_type': 'read', 'google_classification': 'sensitive'}
# {'scope': 'https://www.googleapis.com/auth/classroom.coursework.students', 'api': 'Classroom API', 'api_version': 'v1', 'description': 'Manage course work and grades for students in your Google Classroom classes', 'service': 'Classroom', 'access_type': 'read_write', 'google_classification': 'sensitive'}

# %%
SCOPE_DB  = {}
for i in scopes:
  SCOPE_DB[i['scope']] = {
      'service' : i['service'],
      'access_type' : i['access_type'],
      'google_classification' : i['google_classification'],
      #Dont know if we need the following, keeping commented out untill for sure
      #'api' : i['api'],
      #'api_version' : i['api_version'],
      #'description' : i['description'],
  }

SCOPES_BY_SERVICE = {}
scope_set = set()
for i in scopes:
  #service: [scope(s)]

  #comparing len of scope set to prior tells us if service is already in s_b_s
  len_set_prior = len(scope_set)
  scope_set.add(i['service'])
  if len_set_prior == len(scope_set):
    SCOPES_BY_SERVICE[i['service']].append(i['scope'])
  else:
    SCOPES_BY_SERVICE[i['service']] = [i['scope']]

ALL_SCOPES = []
for i in scopes:
  ALL_SCOPES.append(i['scope'])

# %%
SCOPE_DB
# Out:
# {'https://mail.google.com/': {'service': 'Gmail',
#   'access_type': 'full_access',
#   'google_classification': 'restricted'},
#  'https://www.googleapis.com/auth/gmail.addons.current.action.compose': {'service': 'Gmail',
#   'access_type': 'write',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/gmail.addons.current.message.action': {'service': 'Gmail',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/gmail.addons.current.message.metadata': {'service': 'Gmail',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/gmail.addons.current.message.readonly': {'service': 'Gmail',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/gmail.compose': {'service': 'Gmail',
#   'access_type': 'write',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/gmail.insert': {'service': 'Gmail',
#   'access_type': 'write',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/gmail.labels': {'service': 'Gmail',
#   'access_type': 'read_write',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/gmail.metadata': {'service': 'Gmail',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/gmail.modify': {'service': 'Gmail',
#   'access_type': 'read_write',
#   'google_classification': 'restricted'},
#  'https://www.googleapis.com/auth/gmail.readonly': {'service': 'Gmail',
#   'access_type': 'read',
#   'google_classification': 'restricted'},
#  'https://www.googleapis.com/auth/gmail.send': {'service': 'Gmail',
#   'access_type': 'write',
#   'google_classification': 'restricted'},
#  'https://www.googleapis.com/auth/gmail.settings.basic': {'service': 'Gmail',
#   'access_type': 'read_write',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/gmail.settings.sharing': {'service': 'Gmail',
#   'access_type': 'write',
#   'google_classification': 'restricted'},
#  'https://www.googleapis.com/auth/drive': {'service': 'Drive',
#   'access_type': 'full_access',
#   'google_classification': 'restricted'},
#  'https://www.googleapis.com/auth/drive.appdata': {'service': 'Drive',
#   'access_type': 'read_write',
#   'google_classification': 'non_sensitive'},
#  'https://www.googleapis.com/auth/drive.file': {'service': 'Drive',
#   'access_type': 'read_write',
#   'google_classification': 'non_sensitive'},
#  'https://www.googleapis.com/auth/drive.metadata': {'service': 'Drive',
#   'access_type': 'read_write',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/drive.metadata.readonly': {'service': 'Drive',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/drive.photos.readonly': {'service': 'Drive',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/drive.readonly': {'service': 'Drive',
#   'access_type': 'read',
#   'google_classification': 'restricted'},
#  'https://www.googleapis.com/auth/drive.scripts': {'service': 'Drive',
#   'access_type': 'write',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/drive.activity': {'service': 'Drive',
#   'access_type': 'read_write',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/drive.activity.readonly': {'service': 'Drive',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/calendar': {'service': 'Calendar',
#   'access_type': 'full_access',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/calendar.acls': {'service': 'Calendar',
#   'access_type': 'read_write',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/calendar.acls.readonly': {'service': 'Calendar',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/calendar.app.created': {'service': 'Calendar',
#   'access_type': 'read_write',
#   'google_classification': 'non_sensitive'},
#  'https://www.googleapis.com/auth/calendar.calendarlist': {'service': 'Calendar',
#   'access_type': 'read_write',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/calendar.calendarlist.readonly': {'service': 'Calendar',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/calendar.calendars': {'service': 'Calendar',
#   'access_type': 'read_write',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/calendar.calendars.readonly': {'service': 'Calendar',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/calendar.events': {'service': 'Calendar',
#   'access_type': 'read_write',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/calendar.events.freebusy': {'service': 'Calendar',
#   'access_type': 'read',
#   'google_classification': 'non_sensitive'},
#  'https://www.googleapis.com/auth/calendar.events.owned': {'service': 'Calendar',
#   'access_type': 'read_write',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/calendar.events.owned.readonly': {'service': 'Calendar',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/calendar.events.public.readonly': {'service': 'Calendar',
#   'access_type': 'read',
#   'google_classification': 'non_sensitive'},
#  'https://www.googleapis.com/auth/calendar.events.readonly': {'service': 'Calendar',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/calendar.freebusy': {'service': 'Calendar',
#   'access_type': 'read',
#   'google_classification': 'non_sensitive'},
#  'https://www.googleapis.com/auth/calendar.readonly': {'service': 'Calendar',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/calendar.settings.readonly': {'service': 'Calendar',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/contacts': {'service': 'Contacts',
#   'access_type': 'full_access',
#   'google_classification': 'restricted'},
#  'https://www.googleapis.com/auth/contacts.readonly': {'service': 'Contacts',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/contacts.other.readonly': {'service': 'Contacts',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/directory.readonly': {'service': 'Contacts',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/user.addresses.read': {'service': 'Contacts',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/user.birthday.read': {'service': 'Contacts',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/user.emails.read': {'service': 'Contacts',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/user.gender.read': {'service': 'Contacts',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/user.organization.read': {'service': 'Contacts',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/user.phonenumbers.read': {'service': 'Contacts',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/userinfo.email': {'service': 'Identity',
#   'access_type': 'read',
#   'google_classification': 'non_sensitive'},
#  'https://www.googleapis.com/auth/userinfo.profile': {'service': 'Identity',
#   'access_type': 'read',
#   'google_classification': 'non_sensitive'},
#  'openid': {'service': 'Identity',
#   'access_type': 'read',
#   'google_classification': 'non_sensitive'},
#  'profile': {'service': 'Identity',
#   'access_type': 'read',
#   'google_classification': 'non_sensitive'},
#  'email': {'service': 'Identity',
#   'access_type': 'read',
#   'google_classification': 'non_sensitive'},
#  'https://www.googleapis.com/auth/documents': {'service': 'Docs',
#   'access_type': 'full_access',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/documents.readonly': {'service': 'Docs',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/spreadsheets': {'service': 'Sheets',
#   'access_type': 'full_access',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/spreadsheets.readonly': {'service': 'Sheets',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/presentations': {'service': 'Slides',
#   'access_type': 'full_access',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/presentations.readonly': {'service': 'Slides',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/forms': {'service': 'Forms',
#   'access_type': 'read_write',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/forms.body': {'service': 'Forms',
#   'access_type': 'full_access',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/forms.body.readonly': {'service': 'Forms',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/forms.responses.readonly': {'service': 'Forms',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/forms.currentonly': {'service': 'Forms',
#   'access_type': 'read_write',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/tasks': {'service': 'Tasks',
#   'access_type': 'full_access',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/tasks.readonly': {'service': 'Tasks',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/keep': {'service': 'Keep',
#   'access_type': 'full_access',
#   'google_classification': 'restricted'},
#  'https://www.googleapis.com/auth/keep.readonly': {'service': 'Keep',
#   'access_type': 'read',
#   'google_classification': 'restricted'},
#  'https://www.googleapis.com/auth/youtube': {'service': 'YouTube',
#   'access_type': 'full_access',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/youtube.readonly': {'service': 'YouTube',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/youtube.upload': {'service': 'YouTube',
#   'access_type': 'write',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/youtube.force-ssl': {'service': 'YouTube',
#   'access_type': 'full_access',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/youtubepartner': {'service': 'YouTube',
#   'access_type': 'full_access',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/fitness.activity.read': {'service': 'Fitness',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/fitness.activity.write': {'service': 'Fitness',
#   'access_type': 'write',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/fitness.blood_glucose.read': {'service': 'Fitness',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/fitness.blood_pressure.read': {'service': 'Fitness',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/fitness.body.read': {'service': 'Fitness',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/fitness.heart_rate.read': {'service': 'Fitness',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/fitness.location.read': {'service': 'Fitness',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/fitness.sleep.read': {'service': 'Fitness',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/photoslibrary': {'service': 'Photos',
#   'access_type': 'full_access',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/photoslibrary.readonly': {'service': 'Photos',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/photoslibrary.appendonly': {'service': 'Photos',
#   'access_type': 'write',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/photoslibrary.readonly.appcreateddata': {'service': 'Photos',
#   'access_type': 'read',
#   'google_classification': 'non_sensitive'},
#  'https://www.googleapis.com/auth/chat.messages': {'service': 'Chat',
#   'access_type': 'full_access',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/chat.messages.readonly': {'service': 'Chat',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/chat.spaces': {'service': 'Chat',
#   'access_type': 'read_write',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/chat.spaces.readonly': {'service': 'Chat',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/chat.memberships': {'service': 'Chat',
#   'access_type': 'read_write',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/chat.delete': {'service': 'Chat',
#   'access_type': 'write',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/script.projects': {'service': 'Apps Script',
#   'access_type': 'write',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/script.projects.readonly': {'service': 'Apps Script',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/script.deployments': {'service': 'Apps Script',
#   'access_type': 'write',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/admin.directory.user': {'service': 'Admin',
#   'access_type': 'full_access',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/admin.directory.user.readonly': {'service': 'Admin',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/admin.directory.group': {'service': 'Admin',
#   'access_type': 'full_access',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/admin.directory.domain': {'service': 'Admin',
#   'access_type': 'full_access',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/admin.directory.user.security': {'service': 'Admin',
#   'access_type': 'write',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/admin.directory.rolemanagement': {'service': 'Admin',
#   'access_type': 'full_access',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/admin.reports.audit.readonly': {'service': 'Admin',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/admin.datatransfer': {'service': 'Admin',
#   'access_type': 'read_write',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/cloud-platform': {'service': 'Cloud',
#   'access_type': 'full_access',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/cloud-platform.read-only': {'service': 'Cloud',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/devstorage.full_control': {'service': 'Cloud Storage',
#   'access_type': 'full_access',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/devstorage.read_only': {'service': 'Cloud Storage',
#   'access_type': 'read',
#   'google_classification': 'non_sensitive'},
#  'https://www.googleapis.com/auth/devstorage.read_write': {'service': 'Cloud Storage',
#   'access_type': 'read_write',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/bigquery': {'service': 'BigQuery',
#   'access_type': 'full_access',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/bigquery.insertdata': {'service': 'BigQuery',
#   'access_type': 'write',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/compute': {'service': 'Compute',
#   'access_type': 'full_access',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/compute.readonly': {'service': 'Compute',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/blogger': {'service': 'Blogger',
#   'access_type': 'full_access',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/blogger.readonly': {'service': 'Blogger',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/analytics': {'service': 'Analytics',
#   'access_type': 'full_access',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/analytics.readonly': {'service': 'Analytics',
#   'access_type': 'read',
#   'google_classification': 'non_sensitive'},
#  'https://www.googleapis.com/auth/analytics.edit': {'service': 'Analytics',
#   'access_type': 'write',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/analytics.manage.users': {'service': 'Analytics',
#   'access_type': 'write',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/adsense': {'service': 'AdSense',
#   'access_type': 'full_access',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/adsense.readonly': {'service': 'AdSense',
#   'access_type': 'read',
#   'google_classification': 'non_sensitive'},
#  'https://www.googleapis.com/auth/groups': {'service': 'Groups',
#   'access_type': 'full_access',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/firebase': {'service': 'Firebase',
#   'access_type': 'full_access',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/firebase.readonly': {'service': 'Firebase',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/firebase.messaging': {'service': 'Firebase',
#   'access_type': 'write',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/classroom.courses': {'service': 'Classroom',
#   'access_type': 'full_access',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/classroom.courses.readonly': {'service': 'Classroom',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/classroom.rosters': {'service': 'Classroom',
#   'access_type': 'read_write',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/classroom.profile.emails': {'service': 'Classroom',
#   'access_type': 'read',
#   'google_classification': 'sensitive'},
#  'https://www.googleapis.com/auth/classroom.coursework.students': {'service': 'Classroom',
#   'access_type': 'read_write',
#   'google_classification': 'sensitive'}}

# %%
SERVICE_SENSITIVITY = {
    "Identity":      1,  # public profile, email address
    "Cloud Storage": 2,  # developer data, not personal
    "Analytics":     2,  # website metrics
    "AdSense":       2,  # ad revenue data
    "Blogger":       2,  # blog content
    "Compute":       3,  # infrastructure
    "BigQuery":      3,  # data warehouse
    "Cloud":         3,  # broad cloud access
    "Tasks":         3,  # to-do items
    "Calendar":      3,  # schedule, meetings
    "Classroom":     3,  # educational data
    "Forms":         3,  # survey data
    "Slides":        3,  # presentations
    "YouTube":       3,  # video content
    "Firebase":      3,  # app backend
    "Apps Script":   3,  # automation scripts
    "Groups":        3,  # group memberships
    "Sheets":        4,  # may contain financial/personal data
    "Docs":          4,  # documents, potentially sensitive
    "Photos":        4,  # personal photos
    "Drive":         4,  # all files
    "Fitness":       4,  # health data
    "Chat":          4,  # private conversations
    "Keep":          4,  # personal notes, passwords
    "Contacts":      4,  # personal relationships
    "Gmail":         5,  # email = password resets, phishing, exfiltration
    "Admin":         5  # domain-wide administrative control
}


ACCESS_LEVELS = {
    'read' : 0,        # can view but not change
    'write' : 1,       # can modify or send
    'read_write' : 1,  # can do both
    'full_access' : 2, # complete control including delete
    'admin': 3
}

ADMIN_SCOPES = [ #0 or 1
    "https://www.googleapis.com/auth/admin.directory.user",
    "https://www.googleapis.com/auth/admin.directory.user.security",
    "https://www.googleapis.com/auth/admin.directory.domain",
    "https://www.googleapis.com/auth/admin.directory.rolemanagement",
    "https://www.googleapis.com/auth/admin.datatransfer",
    "https://www.googleapis.com/auth/admin.directory.group",
    "https://www.googleapis.com/auth/cloud-platform",
    "https://www.googleapis.com/auth/analytics.manage.users",
]

TRANSITIVE_SCOPES = [ #0 or 1
    "https://www.googleapis.com/auth/admin.directory.user",
    "https://www.googleapis.com/auth/admin.directory.user.readonly",
    "https://www.googleapis.com/auth/admin.directory.group",
    "https://www.googleapis.com/auth/admin.directory.group.member",
    "https://www.googleapis.com/auth/admin.directory.domain",
    "https://www.googleapis.com/auth/admin.datatransfer",
    "https://www.googleapis.com/auth/admin.directory.rolemanagement",
    "https://www.googleapis.com/auth/directory.readonly",
    "https://www.googleapis.com/auth/cloud-platform",
    "https://www.googleapis.com/auth/classroom.rosters",
    "https://www.googleapis.com/auth/classroom.profile.emails",
    "https://www.googleapis.com/auth/chat.admin.memberships",
    "https://www.googleapis.com/auth/chat.admin.spaces",
    "https://www.googleapis.com/auth/contacts",
    "https://www.googleapis.com/auth/contacts.readonly",
]

# %%
def engineer_features(scope_list, include_offline):
  """
  Inputs:
    scope_list: list of google oauth perms
    include_offline: Boolean value as to whether or not the scope request asks
    for a offline refresh token.

  Purpose: to convert input in form of: [] , Boolean
  into a dictonairy containing the maximum level various secuirity scores present
  in the list of scopes.

  Output: dictionairy containing maximum security scores found in scope list,
  as well as whether or not the scope has persistance (offline access)

  Output format: {
    'data_sensitivity': int: 0-5,

    'access_level': int: 0-3,

    'persistence': int: 0 or 1,
      -whether or not the scope combination requests an offline refresh token

    'transitive_exposure': int: 0 or 1,
      -whether or not a scope was found that would expose other users data

    'scope_count': int,
      -num scopes requested

    'cross_service_breadth': int,
      -how many services the requested scopes span

    'has_restricted_scope': int: 0 or 1
      -whether or not a restricted scope was found
  }
  """

  data_sensitivity = 0
  access_level = 0
  transitive_exposure = 0 #0 = no 1 = yes
  has_restricted_scope = 0 #0 = no 1 = yes
  services = set()

  #chekcing if scope's online bool is true or false
  if include_offline:
    persistence = 1
  else:
    persistence = 0

  for scope in scope_list:
    db_data = SCOPE_DB[scope]

    #sensitivity and access for itterating scope
    itt_sens = SERVICE_SENSITIVITY[db_data['service']]

    itt_access = ACCESS_LEVELS[db_data['access_type']]

    #admin, transitive, and restricted check
    if scope in ADMIN_SCOPES:
      access_level = 3

    if scope in TRANSITIVE_SCOPES:
      transitive_exposure = 1

    if db_data['google_classification'] == 'restricted':
      has_restricted_scope = 1

    #adding service to services:
    services.add(db_data['service'])

    #checking to greatest values:
    data_sensitivity = max(data_sensitivity,itt_sens)

    access_level = max(access_level,itt_access)

    #dont need a max statement for transitive or restricted
    #They stay at 0 if not explicitly modified, only modified if a scope is
    # trans/restricted

  cross_service_breadth = len(services)
  scope_count = len(scope_list)
  score_dict = {
    'data_sensitivity': data_sensitivity,
    'access_level': access_level,
    'persistence': persistence,
    'transitive_exposure': transitive_exposure,
    'scope_count': scope_count,
    'cross_service_breadth': cross_service_breadth,
    'has_restricted_scope': has_restricted_scope

  }
  return score_dict

# %%
def dict_dupe_validation(scope_dict,new_combo):
  """
  Inputs:
  scope_dict: dict, contains all existing scope combos
  new_combo: tuple, new combination to be checked against scope_dict keys

  Purpose: checks new_combo against scope_dict keys

  Returns: Bool
    -True: original combo
    -False: combo already exists
  """
  original_combo = True #assume by default that the combo is orginal
  #this is only changed if the combo is a dupe

  #firstly we must create a version of scope that is same as key format
  new_combo_as_key_format = f'{new_combo[0]},{new_combo[1]}'

  #next we itterate over each key in scope_dict
  for key in scope_dict.keys():
    if key == new_combo_as_key_format:
      original_combo = False
      break
      #if the new combo is the same as a prior combo, original is set to false
      #loop is also broke so it doesn't waste computation going over more when
      #its already found a duplicate

  if original_combo:
    return True #original combo
  else:
    return False #duplicate

# %%
def duplicate_check(all_scope_combos):
  """
  Inputs:
  all_scope_combos: list containing tuples of scope combinations

  Purpose: check and see if there's any duplciates and return their location

  Returns: nested list:
  [
    [index of duplicate, index of coresponding duplicate]
  ]

  """
  duplicate_list = [] #so we can check and validate that dupes are dupes
  for i, scope_to_check in enumerate(all_scope_combos):
    scope_list = scope_to_check[0]
    scope_bool = scope_to_check[1]
    for j, scope_i in enumerate(all_scope_combos):
      if i == j:
        continue
      scope_i_list = scope_i[0]
      scope_i_bool = scope_i[1]
      if scope_list == scope_i_list and scope_bool == scope_i_bool:
        duplicate_list.append([i,j])

  return duplicate_list

# %%
def remove_duplicates(duplicate_list,all_scope_combos):
  """
  Inputs:
  duplicate_list: nested list containing indicies of duplicates:
      [
        [index of duplicate, index of coresponding duplicate]
      ]
  all_scope_combos: list containing tuples of scope combinations

  Purpose: remove duplicate indicies from all_scope_combos

  returns: all_scope_combos: list containing tuples of scope combinations
  without any duplciates

  """
  #removing duplciate entrys from duplicate list
  bigger_idx_set = set()
  for dupe_pair in duplicate_list:
    if dupe_pair[0] > dupe_pair[1]:
      bigger_idx_set.add(dupe_pair[0])
    else:
      bigger_idx_set.add(dupe_pair[1])

  bigger_idx_list = list(bigger_idx_set)
  bigger_idx_list.sort(reverse=True)

  for idx_to_drop in bigger_idx_list:
    del all_scope_combos[idx_to_drop]

  return all_scope_combos

# %%
github_manifest_combinations = [
    (['https://mail.google.com/','https://www.googleapis.com/auth/directory.readonly'],True,'A desktop email client requires full mailbox access to display, compose, and delete emails'),
    (['https://www.googleapis.com/auth/gmail.modify','https://www.googleapis.com/auth/gmail.labels','https://www.googleapis.com/auth/contacts.other.readonly'],True,'Webmail managers need to read and modify emails (move, archive, label) and manage labels for folder-like organization.'),
    (['https://www.googleapis.com/auth/gmail.readonly','https://www.googleapis.com/auth/gmail.send','https://www.googleapis.com/auth/gmail.compose'],True,'A helpdesk reads incoming support emails, drafts responses using templates, and sends replies.'),
    (['https://www.googleapis.com/auth/gmail.send','https://www.googleapis.com/auth/gmail.readonly','https://www.googleapis.com/auth/contacts.readonly','https://www.googleapis.com/auth/calendar.events'],True,'A CRM reads emails to log conversation history, sends outreach emails, reads contacts to build the lead database, and accesses calendar events to track meetings.'),
    (['https://www.googleapis.com/auth/contacts','https://www.googleapis.com/auth/gmail.send','https://www.googleapis.com/auth/calendar.events','https://www.googleapis.com/auth/drive.file'],True,'Sales platforms need write access to contacts, email sending, calendar access, and app-specific Drive access.'),
    (['https://www.googleapis.com/auth/gmail.readonly','https://www.googleapis.com/auth/contacts.readonly','https://www.googleapis.com/auth/calendar.calendars.readonly'],True,"A read-only CRM sync only ingests data without modifying the user's account"),
    (['https://www.googleapis.com/auth/calendar.events','https://www.googleapis.com/auth/tasks','https://www.googleapis.com/auth/drive.file'],False,'A project management tool syncs calendar events to show deadlines on a project timeline, syncs tasks for to-do tracking, and attaches files from Drive to cards or tickets.'),
    (['https://www.googleapis.com/auth/drive.file','https://www.googleapis.com/auth/spreadsheets'],False,'Some open-source tools store their board state in a Google Sheet rather than a dedicated database'),
    (['https://www.googleapis.com/auth/calendar.events.readonly','https://www.googleapis.com/auth/tasks.readonly'],False,"Time trackers only need to observe the user's calendar and tasks to log time automatically."),
    (['https://mail.google.com/','https://www.googleapis.com/auth/drive','https://www.googleapis.com/auth/calendar','https://www.googleapis.com/auth/contacts'],True,"A backup tool must access the user's complete data across all services."),
    (['https://www.googleapis.com/auth/drive','https://www.googleapis.com/auth/calendar','https://www.googleapis.com/auth/spreadsheets'],True,'Migration tools need full Drive access plus explicit Docs and Sheets scopes to preserve native document formatting during cross-platform transfers.'),
    (['https://www.googleapis.com/auth/gmail.readonly','https://www.googleapis.com/auth/drive.readonly'],True,'An email archiver reads all mail and optionally reads Drive attachments for a complete archive.'),
    (['https://www.googleapis.com/auth/spreadsheets','https://www.googleapis.com/auth/gmail.send','https://www.googleapis.com/auth/drive.file'],False,'A mail merge reads recipient lists from a spreadsheet, sends personalized emails, and accesses Drive for email template files.'),
    (['https://www.googleapis.com/auth/spreadsheets','https://www.googleapis.com/auth/gmail.send','https://www.googleapis.com/auth/contacts.readonly'],False,'Similar to mail merge but uses contacts for recipient data instead of or in addition to a spreadsheet.'),
    (['https://www.googleapis.com/auth/script.projects','https://www.googleapis.com/auth/drive','https://www.googleapis.com/auth/spreadsheets','https://www.googleapis.com/auth/gmail.send'],True,'General-purpose automation platforms need broad access because they execute user-defined workflows that may span multiple services'),
    (['https://www.googleapis.com/auth/forms.body','https://www.googleapis.com/auth/forms.responses.readonly','https://www.googleapis.com/auth/spreadsheets','https://www.googleapis.com/auth/gmail.send'],False,'A form auto-responder watches for new form submissions, logs responses to a spreadsheet for record-keeping, and sends a confirmation email to each respondent.'),
    (['https://www.googleapis.com/auth/analytics.readonly','https://www.googleapis.com/auth/spreadsheets'],False,'These tools pull Google Analytics data and write it to a spreadsheet for custom dashboarding.'),
    (['https://www.googleapis.com/auth/analytics','https://www.googleapis.com/auth/bigquery'],False,'For large-scale analytics, data is piped from Google Analytics into BigQuery for SQL-based analysis.'),
    (['https://www.googleapis.com/auth/admin.directory.user.readonly','https://www.googleapis.com/auth/spreadsheets'],False,'Security teams export Workspace audit logs to spreadsheets for compliance reporting.'),
    (['https://www.googleapis.com/auth/youtube.upload','https://www.googleapis.com/auth/drive.readonly'],False,'These tools read video files from Drive and upload them to YouTube on a schedule.'),
    (['https://www.googleapis.com/auth/youtube','https://www.googleapis.com/auth/analytics.readonly'],True,'Creator dashboards need full YouTube access for channel management plus analytics for performance metrics.'),
    (['https://www.googleapis.com/auth/photoslibrary','https://www.googleapis.com/auth/drive'],True,'Photo organizers sync between Google Photos and Drive folders, requiring full access to both services.'),
    (['https://www.googleapis.com/auth/classroom.courses','https://www.googleapis.com/auth/classroom.rosters','https://www.googleapis.com/auth/drive.file','https://www.googleapis.com/auth/forms.body'],False,'A learning management system integration needs to read and create courses, access class rosters for enrollment sync, attach files to assignments via Drive, and create quizzes via Forms.'),
    (['https://www.googleapis.com/auth/classroom.coursework.students','https://www.googleapis.com/auth/spreadsheets','https://www.googleapis.com/auth/gmail.send'],False,'A grade notification tool reads student coursework and grades, exports them to a spreadsheet for record-keeping, and sends email notifications to students or parents.'),
    (['https://www.googleapis.com/auth/chat.messages','https://www.googleapis.com/auth/chat.spaces','https://www.googleapis.com/auth/calendar.events.readonly'],False,'A reminder bot reads upcoming calendar events and sends notification messages into Chat spaces.'),
    (['https://www.googleapis.com/auth/chat.messages','https://www.googleapis.com/auth/drive.readonly'],False,'A file sharing bot allows users to search and share Drive files directly within Chat.'),
    (['openid','email','profile'],False,'The minimal sign-in scope set used by virtually every web application offering Google SSO.'),
    (['openid','email','https://www.googleapis.com/auth/userinfo.email','https://www.googleapis.com/auth/userinfo.profile'],False,'Some OAuth libraries request the explicit userinfo scopes alongside the shorthand scopes.'),
    (['https://www.googleapis.com/auth/admin.directory.user','https://www.googleapis.com/auth/admin.directory.group','https://www.googleapis.com/auth/admin.directory.user.security'],True,'IT admin tools manage user accounts, group memberships, and security settings.'),
    (['https://www.googleapis.com/auth/admin.directory.user.readonly','https://www.googleapis.com/auth/admin.reports.audit.readonly'],False,'Security dashboards need read-only access to the user directory (to identify accounts) and audit logs. '),
    (['https://www.googleapis.com/auth/admin.directory.user','https://www.googleapis.com/auth/admin.datatransfer','https://www.googleapis.com/auth/admin.directory.domain'],True,'Domain migration requires user management (to recreate accounts), data transfer, and domain provisioning.'),
    (['https://www.googleapis.com/auth/cloud-platform','https://www.googleapis.com/auth/compute'],True,'Deployment tools need broad cloud-platform access to provision infrastructure and compute access to manage virtual machines.'),
    (['https://www.googleapis.com/auth/devstorage.read_write','https://www.googleapis.com/auth/bigquery'],False,'Data pipelines move data between Cloud Storage and BigQuery. '),
    (['https://www.googleapis.com/auth/cloud-platform.read-only','https://www.googleapis.com/auth/compute.readonly'],False,''),
]
len(github_manifest_combinations)
# Out:
# 34

# %%
engineer_features(github_manifest_combinations[0][0],github_manifest_combinations[0][1])
# Out:
# {'data_sensitivity': 5,
#  'access_level': 2,
#  'persistence': 1,
#  'transitive_exposure': 1,
#  'scope_count': 2,
#  'cross_service_breadth': 2,
#  'has_restricted_scope': 1}

# %%
published_attack_patterns_combinations = [
    (['https://mail.google.com/','https://www.googleapis.com/auth/drive','https://www.googleapis.com/auth/contacts'],True,'Full data exfiltration via consent phishing.'),
    (['https://mail.google.com/','https://www.googleapis.com/auth/contacts','https://www.googleapis.com/auth/calendar'],True,'Consent phishing targeting email, contacts, and calendar.'),
    (['https://www.googleapis.com/auth/gmail.send','https://www.googleapis.com/auth/contacts.readonly',],True,'Send-as phishing with contact harvesting.'),
    (['https://mail.google.com/'],True,'Full Gmail takeover via a single scope.'),
    (['https://www.googleapis.com/auth/drive'],True,'Persistent Drive access via token abuse.'),
    (['https://www.googleapis.com/auth/gmail.send','https://www.googleapis.com/auth/gmail.readonly','https://www.googleapis.com/auth/drive','https://www.googleapis.com/auth/contacts'],True,'Comprehensive spearphishing setup.'),
    (['https://www.googleapis.com/auth/gmail.send','https://www.googleapis.com/auth/gmail.readonly','https://www.googleapis.com/auth/contacts.readonly'],True,'Email impersonation setup.'),
    (['https://mail.google.com/','https://www.googleapis.com/auth/gmail.settings.sharing'],True,'Full email access with forwarding rule injection.'),
    (['https://www.googleapis.com/auth/gmail.modify','https://www.googleapis.com/auth/gmail.settings.basic'],True,'Email modification with filter manipulation.'),
    (['https://www.googleapis.com/auth/admin.directory.user','https://www.googleapis.com/auth/admin.directory.user.security','https://www.googleapis.com/auth/admin.directory.rolemanagement'],True,'Admin account takeover.'),
    (['https://www.googleapis.com/auth/cloud-platform','https://www.googleapis.com/auth/compute'],True,'Cloud infrastructure compromise.'),
    (['https://www.googleapis.com/auth/admin.directory.user','https://www.googleapis.com/auth/admin.directory.group','https://www.googleapis.com/auth/admin.directory.domain','https://www.googleapis.com/auth/admin.datatransfer'],True,'Full domain admin compromise.'),
    (['https://www.googleapis.com/auth/admin.directory.user','https://mail.google.com/'],True,'Admin plus full email access enables user impersonation.'),
    (['https://www.googleapis.com/auth/drive','https://www.googleapis.com/auth/documents','https://www.googleapis.com/auth/spreadsheets'],True,'Document exfiltration targeting all file types.'),
    (['https://www.googleapis.com/auth/drive.readonly','https://www.googleapis.com/auth/gmail.readonly','https://www.googleapis.com/auth/calendar.acls.readonly','https://www.googleapis.com/auth/directory.readonly'],True,'Passive surveillance using read-only scopes.'),
    (['https://www.googleapis.com/auth/photoslibrary','https://www.googleapis.com/auth/drive','https://www.googleapis.com/auth/contacts'],True,'Personal data theft targeting photos, files, and contacts.'),
    (['https://www.googleapis.com/auth/keep','https://www.googleapis.com/auth/drive','https://www.googleapis.com/auth/gmail.readonly'],True,'Credential harvesting from notes and files.'),
    (['https://www.googleapis.com/auth/fitness.blood_glucose.read','https://www.googleapis.com/auth/fitness.blood_pressure.read','https://www.googleapis.com/auth/fitness.heart_rate.read','https://www.googleapis.com/auth/fitness.body.read'],True,'Health data theft from Google Fitness. Medical data including blood glucose, blood pressure, heart rate, and body measurements is highly sensitive and subject to health privacy regulations.'),
    (['https://mail.google.com/','https://www.googleapis.com/auth/drive','https://www.googleapis.com/auth/calendar','https://www.googleapis.com/auth/contacts','https://www.googleapis.com/auth/tasks','https://www.googleapis.com/auth/keep'],True,'Massively over-privileged app requesting access to six distinct services.'),
    (['https://www.googleapis.com/auth/cloud-platform','https://mail.google.com/','https://www.googleapis.com/auth/drive','https://www.googleapis.com/auth/admin.directory.user'],True,'Maximum privilege request spanning cloud infrastructure, email, files, and user administration'),
    (['https://www.googleapis.com/auth/gmail.modify','https://www.googleapis.com/auth/drive','https://www.googleapis.com/auth/calendar','https://www.googleapis.com/auth/contacts','https://www.googleapis.com/auth/youtube','https://www.googleapis.com/auth/photoslibrary'],True,'Kitchen-sink scope request spanning six unrelated services.')
]
len(published_attack_patterns_combinations)
# Out:
# 21

# %%
#Creating Scope Combinations
#I did include the example ones from the Dataset Creation document.
#These were all generated by looking at the json file
student_created_scope_combinations = [
    (['openid','profile','email','https://www.googleapis.com/auth/fitness.activity.read','https://www.googleapis.com/auth/fitness.body.read','https://www.googleapis.com/auth/spreadsheets'],True,'Offline access to actively monitor fitness activity and have access to body metrics and full access to Google Sheets'),
    (['openid','profile','email','https://www.googleapis.com/auth/youtube','https://www.googleapis.com/auth/drive.file'],False,'Full online access to YouTube account, including uploading and managing videos. Also includes access to Google Drive files you use with this application.'),
    (['openid','profile','email','https://www.googleapis.com/auth/contacts.readonly','https://www.googleapis.com/auth/gmail.compose'],False,'Authentication, email adress, personalization data and manage and send drafts as well as read only access to contacts while online.'),
    (['openid','profile','email','https://www.googleapis.com/auth/devstorage.read_write','https://www.googleapis.com/auth/drive.file'],True,'Authentication, email adress, personalization data and full offline read/write access to all files in cloud storage and files in drive that you use with this app.'),
    (['openid','profile','email','https://www.googleapis.com/auth/photoslibrary',],False,'Authentication, email adress, personalization data and full access to photos and cloud storage while online.'),
    (['openid','profile','email','https://www.googleapis.com/auth/presentations','https://www.googleapis.com/auth/documents'],False,'Authentication, email adress, personalization data and see, edit, and create Google Docs and Google Presentations while online.'),
    (['openid','profile','email','https://www.googleapis.com/auth/tasks.readonly','https://www.googleapis.com/auth/calendar.events.readonly'],False,'Authentication, email adress, personalization data and online access to read all Google Tasks and all Google Calendar events.'),
    (['openid','profile','email','https://www.googleapis.com/auth/firebase','https://www.googleapis.com/auth/compute'], False, 'Authentication, email adress, personalization data and online access to managing Firebase and Google Compute Engine resources '),
    (['openid','profile','email','https://www.googleapis.com/auth/adsense.readonly','https://www.googleapis.com/auth/youtube.readonly'], False, 'Online authentication with read only access to AdSense revenue data and YouTube channel analytics.'),
    (['openid','profile','email','https://www.googleapis.com/auth/chat.messages', 'https://www.googleapis.com/auth/contacts.readonly'],False,'Online access to composing, seeing, sending, updating, and deleting messages in Google Chat as well as read only access to contacts.'),
    (['openid','profile','email','https://www.googleapis.com/auth/presentations.readonly','https://www.googleapis.com/auth/documents.readonly','https://www.googleapis.com/auth/photoslibrary.readonly','https://www.googleapis.com/auth/spreadsheets.readonly'],False,'Online read only access to Google Sheets, Google Documents, Google Presentations and Google Photos'),
    (['openid','profile','email','https://www.googleapis.com/auth/userinfo.profile','https://www.googleapis.com/auth/analytics','https://www.googleapis.com/auth/user.addresses.read'],False,'Online access to see any personal information you have made publically avaible as well as viewing and managing your Google Analytics data. Also enables viewing of your street address.'),
    (['openid','profile','email','https://www.googleapis.com/auth/classroom.profile.emails','https://www.googleapis.com/auth/gmail.send',],False,'Online access to view the email adress of people in your Google Classroom classes aswell as write access to send mail via GMail.'),
    (['https://www.googleapis.com/auth/bigquery','https://www.googleapis.com/auth/devstorage.read_write'], True, 'Full offline access to Google BigQuery for data processing and read write access to Google Cloud Storage.'),
    (['openid','profile','email','https://www.googleapis.com/auth/firebase','https://www.googleapis.com/auth/spreadsheets','https://www.googleapis.com/auth/script.deployments','https://www.googleapis.com/auth/script.projects'],True,'Full offline access to Firebase data and settings, full access to your Google Sheets, full access to App Scripts projects and deployments'),
    (['https://www.googleapis.com/auth/admin.directory.rolemanagement','https://www.googleapis.com/auth/admin.directory.user.readonly','https://www.googleapis.com/auth/gmail.settings.sharing'],False,'Online access to managing permisioning in your domain, reading user directory, and managing email sharing settings.'),
    (['openid','profile','email','https://www.googleapis.com/auth/keep', 'https://www.googleapis.com/auth/tasks', 'https://www.googleapis.com/auth/calendar.events.owned'],False,'Online read write access to personal Google Calendar events, Google Keep notes, and Google Tasks.'),
    (['openid','profile','email','https://www.googleapis.com/auth/admin.reports.audit.readonly', 'https://www.googleapis.com/auth/analytics.readonly', 'https://www.googleapis.com/auth/spreadsheets', 'https://www.googleapis.com/auth/drive.file'],False,'Read only access to Google Admin report audits and analytics with full access to Google Drive and Google Sheets.'),
    (['openid','profile','email','https://www.googleapis.com/auth/chat.messages','https://www.googleapis.com/auth/drive.readonly'],False,'Full access to composing, sending, updating, and deleting Google Chat messages with read only access to Google Drive.'),
    (['https://www.googleapis.com/auth/devstorage.read_write','https://www.googleapis.com/auth/admin.datatransfer'], True, 'Full offline access to read and write to Google Cloud Storage and manage data transfers between users in your organization, for automated movement of data.'),
    (['openid','profile','email','https://www.googleapis.com/auth/blogger','https://www.googleapis.com/auth/analytics','https://www.googleapis.com/auth/script.projects'],True,'Full offline access to your Google Blogger account, Google Analytics, and Google App Scripts projects'),
    (["openid", "profile", "email"], False, "Basic sign-in only"),
    (["openid", "email"], False, "Minimal sign-in"),
    (['openid','profile','email',"https://www.googleapis.com/auth/userinfo.email", "https://www.googleapis.com/auth/userinfo.profile"], False, "Profile + email sign-in"),
    (["openid","profile", "email", "https://www.googleapis.com/auth/userinfo.email"], False, "Redundant sign-in scopes"),
    (['openid','profile','email','https://www.googleapis.com/auth/documents', 'https://www.googleapis.com/auth/forms.body', 'https://www.googleapis.com/auth/drive.file'],False,'Online authentication with basic profile info, full access to create and edit Google Docs and Forms, and access to Drive file'),
    (['openid','profile','email','https://www.googleapis.com/auth/firebase','https://www.googleapis.com/auth/fitness.blood_glucose.read'],True,'Authentication with profile info, full offline access to firebase and blood glucose levels.'),
    (['openid','profile','email','https://www.googleapis.com/auth/gmail.readonly','https://www.googleapis.com/auth/calendar.events.owned'],False,'Authentication, read only for gmail and full access to owned calendars'),
    (['openid','profile','email','https://www.googleapis.com/auth/classroom.coursework.students','https://www.googleapis.com/auth/spreadsheets'],False,'Authentication, access to coursework and grades for students in your classrooms and full access to Google Sheets.'),
    (['https://www.googleapis.com/auth/bigquery.insertdata','https://www.googleapis.com/auth/drive.readonly'],False,'Access to inserting data into BigQuery and access to see and download all Google Drive files.'),
    (['openid','profile','email','https://www.googleapis.com/auth/drive.readonly','https://www.googleapis.com/auth/youtube.upload'],False,'Online authentication media uploader to YouTube with full download access to Drive'),
    (['openid','profile','email','https://www.googleapis.com/auth/forms.responses.readonly','https://www.googleapis.com/auth/gmail.send'],False,'Online authentication with basic profile information that has read access to form responces and abillity to send gmail.'),
    (['openid','profile','email','https://www.googleapis.com/auth/analytics.readonly','https://www.googleapis.com/auth/spreadsheets'],True,'Offline with read access to your Google Analytics and AdSense data and full access to Google Sheets'),
    (['openid','profile','email','https://www.googleapis.com/auth/gmail.send', 'https://www.googleapis.com/auth/gmail.readonly', 'https://www.googleapis.com/auth/spreadsheets', 'https://www.googleapis.com/auth/drive.file', 'https://www.googleapis.com/auth/contacts.readonly'],False,'Online authentication and profile information with send/read permisons for gmail, read only for contacts, and full access to drive and spreadsheets.'),
    (['openid','profile','email','https://www.googleapis.com/auth/blogger','https://www.googleapis.com/auth/documents.readonly'],False,'Online read only access to Google Documents and full access to your Blogger account'),
    (['openid','profile','email','https://www.googleapis.com/auth/drive.scripts','https://www.googleapis.com/auth/script.projects','https://www.googleapis.com/auth/drive.activity'],True,'Authentication with offline access to modify your Google Drive App Scripts, Google App Scripts, and Google Drive Activity.'),
    (['openid','profile','email','https://www.googleapis.com/auth/forms.responses.readonly','https://www.googleapis.com/auth/calendar.events.owned'],False,'Online authentication, access to read only data coming from forms you own and full access to modify calendars you own.'),
    (['openid','profile','email','https://www.googleapis.com/auth/gmail.addons.current.message.readonly', 'https://www.googleapis.com/auth/chat.messages'],False,'Online authentication read only access to gmail and full access to Google Chat.'),
    (['openid','profile','email','https://www.googleapis.com/auth/calendar.events.owned','https://www.googleapis.com/auth/chat.messages.readonly'],False,'Online read only access to Google Chat messages and full access to modify s you own.'),
    (['https://www.googleapis.com/auth/bigquery','https://www.googleapis.com/auth/devstorage.read_write','https://www.googleapis.com/auth/spreadsheets'],True,'Offline full access to BigQuery, read write access to Cloud Storage, and full access to Google Sheets.'),
    (['openid','profile','email','https://www.googleapis.com/auth/gmail.send','https://www.googleapis.com/auth/admin.datatransfer'], False, 'Online authentication with ability to send Gmail notifications and access to view and manage data transfers between users in your organization.'),
    (['openid','profile','email','https://www.googleapis.com/auth/drive.activity.readonly','https://www.googleapis.com/auth/gmail.send'],True,'Offline access to read google drive activity and send mail via gmail on your behalf.'),
    (['openid','profile','email','https://www.googleapis.com/auth/gmail.labels','https://www.googleapis.com/auth/gmail.metadata'],False,'Online access to managing your email labels and read only access to email metadata.'),
    (['openid','profile','email','https://www.googleapis.com/auth/compute.readonly','https://www.googleapis.com/auth/firebase.readonly','https://www.googleapis.com/auth/spreadsheets'],False,'Online read-only access to your Firebase data as well as Google Compute data and full access to Google Sheets.'),
    (['openid','profile','email','https://www.googleapis.com/auth/firebase.readonly','https://www.googleapis.com/auth/analytics.readonly'],True,'Offline read-only access to Google Firebase and Google Analytics data'),
    (['https://www.googleapis.com/auth/admin.directory.user.security','https://www.googleapis.com/auth/admin.directory.domain','https://www.googleapis.com/auth/admin.directory.rolemanagement','https://www.googleapis.com/auth/spreadsheets.readonly'],False,'Online read-only access to Google Sheets, access to provisioning of domains for users, role management, and data access permisions for users in your domain.'),
    (['openid','profile','email','https://www.googleapis.com/auth/gmail.send','https://www.googleapis.com/auth/classroom.profile.emails','https://www.googleapis.com/auth/calendar.events.readonly'],False,'Online access send emails on your behalf, read only access to the emails of people in your classrooms, and read only access to all events on your Google Calendar.'),
    (['openid','profile','email','https://www.googleapis.com/auth/groups','https://www.googleapis.com/auth/contacts.readonly'],False,'Online full access to groups and read only access to your contacts.'),
    (['openid','profile','email','https://www.googleapis.com/auth/adsense.readonly','https://www.googleapis.com/auth/analytics.readonly'],False,'Online read only access to AdSense data and Analytics'),
    (['openid','profile','email','https://www.googleapis.com/auth/photoslibrary.appendonly','https://www.googleapis.com/auth/chat.messages.readonly','https://www.googleapis.com/auth/gmail.addons.current.message.readonly'],False,'Online access to append to Google Photos library, read all Google Chat messages, and read Gmail messages when the add-on is active ')
]
len(student_created_scope_combinations)
# Out:
# 50

# %%
#adding where each scope combo came from to each scope
#github:
for idx, scope_combo in enumerate(copy.deepcopy(github_manifest_combinations)):
  #using deep copy here as a safe guard as we are itterating over a list containing
  #nested containers (tuples) while modifying said values.

  #creating a list copy so that we can edit it:
  new_scope_combo = list(scope_combo)

  #adding where the scope combo is from to the list copy
  new_scope_combo.append('Github Manifest Combinations')
  #converting to tuple and reasigning coresponding idx to new value
  new_scope_combo = tuple(new_scope_combo)
  github_manifest_combinations[idx] = new_scope_combo

#malicious attack patterns:
for idx, scope_combo in enumerate(copy.deepcopy(published_attack_patterns_combinations)):
  #using deep copy here as a safe guard as we are itterating over a list containing
  #nested containers (tuples) while modifying said values.

  #creating a list copy so that we can edit it:
  new_scope_combo = list(scope_combo)

  #adding where the scope combo is from to the list copy
  new_scope_combo.append('Published Attack Patterns')
  #converting to tuple and reasigning coresponding idx to new value
  new_scope_combo = tuple(new_scope_combo)
  published_attack_patterns_combinations[idx] = new_scope_combo

#student gen:
for idx, scope_combo in enumerate(copy.deepcopy(student_created_scope_combinations)):
  #using deep copy here as a safe guard as we are itterating over a list containing
  #nested containers (tuples) while modifying said values.

  #creating a list copy so that we can edit it:
  new_scope_combo = list(scope_combo)

  #adding where the scope combo is from to the list copy
  new_scope_combo.append('Student Created')
  #converting to tuple and reasigning coresponding idx to new value
  new_scope_combo = tuple(new_scope_combo)
  student_created_scope_combinations[idx] = new_scope_combo

# %%
#combinding all current scope combinations
all_scope_combinations = student_created_scope_combinations + published_attack_patterns_combinations + github_manifest_combinations

# %%
duplicate_list = duplicate_check(all_scope_combinations)
print(duplicate_list)
# Out:
# [[60, 102], [102, 60]]

# %%
all_scope_combinations = remove_duplicates(duplicate_list,all_scope_combinations)

len(all_scope_combinations)
# Out:
# 104

# %%
"""
This scope dict will be used to validate that we are not adding duplicates.
Every single time that a scope combo will be added, it will be checked against
the keys in this dict to prevent duplicates.
Format:
{
  ([Scopes], OnlineBool) : ([Scopes], OnlineBool, 'desc', 'method used to generate')
}
"""
scope_dict = {}
#populating scope_dict
for item in all_scope_combinations:
  copied_item = copy.deepcopy(item)
  scope_dict[f'{copied_item[0]},{copied_item[1]}'] = copied_item

scope_dict
# Out:
# {"['openid', 'profile', 'email', 'https://www.googleapis.com/auth/fitness.activity.read', 'https://www.googleapis.com/auth/fitness.body.read', 'https://www.googleapis.com/auth/spreadsheets'],True": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/fitness.activity.read',
#    'https://www.googleapis.com/auth/fitness.body.read',
#    'https://www.googleapis.com/auth/spreadsheets'],
#   True,
#   'Offline access to actively monitor fitness activity and have access to body metrics and full access to Google Sheets',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/youtube', 'https://www.googleapis.com/auth/drive.file'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/youtube',
#    'https://www.googleapis.com/auth/drive.file'],
#   False,
#   'Full online access to YouTube account, including uploading and managing videos. Also includes access to Google Drive files you use with this application.',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/contacts.readonly', 'https://www.googleapis.com/auth/gmail.compose'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/contacts.readonly',
#    'https://www.googleapis.com/auth/gmail.compose'],
#   False,
#   'Authentication, email adress, personalization data and manage and send drafts as well as read only access to contacts while online.',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/drive.file'],True": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/devstorage.read_write',
#    'https://www.googleapis.com/auth/drive.file'],
#   True,
#   'Authentication, email adress, personalization data and full offline read/write access to all files in cloud storage and files in drive that you use with this app.',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/photoslibrary'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/photoslibrary'],
#   False,
#   'Authentication, email adress, personalization data and full access to photos and cloud storage while online.',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/presentations', 'https://www.googleapis.com/auth/documents'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/presentations',
#    'https://www.googleapis.com/auth/documents'],
#   False,
#   'Authentication, email adress, personalization data and see, edit, and create Google Docs and Google Presentations while online.',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/tasks.readonly', 'https://www.googleapis.com/auth/calendar.events.readonly'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/tasks.readonly',
#    'https://www.googleapis.com/auth/calendar.events.readonly'],
#   False,
#   'Authentication, email adress, personalization data and online access to read all Google Tasks and all Google Calendar events.',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/firebase', 'https://www.googleapis.com/auth/compute'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/firebase',
#    'https://www.googleapis.com/auth/compute'],
#   False,
#   'Authentication, email adress, personalization data and online access to managing Firebase and Google Compute Engine resources ',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/adsense.readonly', 'https://www.googleapis.com/auth/youtube.readonly'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/adsense.readonly',
#    'https://www.googleapis.com/auth/youtube.readonly'],
#   False,
#   'Online authentication with read only access to AdSense revenue data and YouTube channel analytics.',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/chat.messages', 'https://www.googleapis.com/auth/contacts.readonly'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/chat.messages',
#    'https://www.googleapis.com/auth/contacts.readonly'],
#   False,
#   'Online access to composing, seeing, sending, updating, and deleting messages in Google Chat as well as read only access to contacts.',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/presentations.readonly', 'https://www.googleapis.com/auth/documents.readonly', 'https://www.googleapis.com/auth/photoslibrary.readonly', 'https://www.googleapis.com/auth/spreadsheets.readonly'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/presentations.readonly',
#    'https://www.googleapis.com/auth/documents.readonly',
#    'https://www.googleapis.com/auth/photoslibrary.readonly',
#    'https://www.googleapis.com/auth/spreadsheets.readonly'],
#   False,
#   'Online read only access to Google Sheets, Google Documents, Google Presentations and Google Photos',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/userinfo.profile', 'https://www.googleapis.com/auth/analytics', 'https://www.googleapis.com/auth/user.addresses.read'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/userinfo.profile',
#    'https://www.googleapis.com/auth/analytics',
#    'https://www.googleapis.com/auth/user.addresses.read'],
#   False,
#   'Online access to see any personal information you have made publically avaible as well as viewing and managing your Google Analytics data. Also enables viewing of your street address.',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/classroom.profile.emails', 'https://www.googleapis.com/auth/gmail.send'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/classroom.profile.emails',
#    'https://www.googleapis.com/auth/gmail.send'],
#   False,
#   'Online access to view the email adress of people in your Google Classroom classes aswell as write access to send mail via GMail.',
#   'Student Created'),
#  "['https://www.googleapis.com/auth/bigquery', 'https://www.googleapis.com/auth/devstorage.read_write'],True": (['https://www.googleapis.com/auth/bigquery',
#    'https://www.googleapis.com/auth/devstorage.read_write'],
#   True,
#   'Full offline access to Google BigQuery for data processing and read write access to Google Cloud Storage.',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/firebase', 'https://www.googleapis.com/auth/spreadsheets', 'https://www.googleapis.com/auth/script.deployments', 'https://www.googleapis.com/auth/script.projects'],True": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/firebase',
#    'https://www.googleapis.com/auth/spreadsheets',
#    'https://www.googleapis.com/auth/script.deployments',
#    'https://www.googleapis.com/auth/script.projects'],
#   True,
#   'Full offline access to Firebase data and settings, full access to your Google Sheets, full access to App Scripts projects and deployments',
#   'Student Created'),
#  "['https://www.googleapis.com/auth/admin.directory.rolemanagement', 'https://www.googleapis.com/auth/admin.directory.user.readonly', 'https://www.googleapis.com/auth/gmail.settings.sharing'],False": (['https://www.googleapis.com/auth/admin.directory.rolemanagement',
#    'https://www.googleapis.com/auth/admin.directory.user.readonly',
#    'https://www.googleapis.com/auth/gmail.settings.sharing'],
#   False,
#   'Online access to managing permisioning in your domain, reading user directory, and managing email sharing settings.',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/keep', 'https://www.googleapis.com/auth/tasks', 'https://www.googleapis.com/auth/calendar.events.owned'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/keep',
#    'https://www.googleapis.com/auth/tasks',
#    'https://www.googleapis.com/auth/calendar.events.owned'],
#   False,
#   'Online read write access to personal Google Calendar events, Google Keep notes, and Google Tasks.',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/admin.reports.audit.readonly', 'https://www.googleapis.com/auth/analytics.readonly', 'https://www.googleapis.com/auth/spreadsheets', 'https://www.googleapis.com/auth/drive.file'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/admin.reports.audit.readonly',
#    'https://www.googleapis.com/auth/analytics.readonly',
#    'https://www.googleapis.com/auth/spreadsheets',
#    'https://www.googleapis.com/auth/drive.file'],
#   False,
#   'Read only access to Google Admin report audits and analytics with full access to Google Drive and Google Sheets.',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/chat.messages', 'https://www.googleapis.com/auth/drive.readonly'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/chat.messages',
#    'https://www.googleapis.com/auth/drive.readonly'],
#   False,
#   'Full access to composing, sending, updating, and deleting Google Chat messages with read only access to Google Drive.',
#   'Student Created'),
#  "['https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/admin.datatransfer'],True": (['https://www.googleapis.com/auth/devstorage.read_write',
#    'https://www.googleapis.com/auth/admin.datatransfer'],
#   True,
#   'Full offline access to read and write to Google Cloud Storage and manage data transfers between users in your organization, for automated movement of data.',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/blogger', 'https://www.googleapis.com/auth/analytics', 'https://www.googleapis.com/auth/script.projects'],True": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/blogger',
#    'https://www.googleapis.com/auth/analytics',
#    'https://www.googleapis.com/auth/script.projects'],
#   True,
#   'Full offline access to your Google Blogger account, Google Analytics, and Google App Scripts projects',
#   'Student Created'),
#  "['openid', 'profile', 'email'],False": (['openid', 'profile', 'email'],
#   False,
#   'Basic sign-in only',
#   'Student Created'),
#  "['openid', 'email'],False": (['openid', 'email'],
#   False,
#   'Minimal sign-in',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/userinfo.email', 'https://www.googleapis.com/auth/userinfo.profile'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/userinfo.email',
#    'https://www.googleapis.com/auth/userinfo.profile'],
#   False,
#   'Profile + email sign-in',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/userinfo.email'],
#   False,
#   'Redundant sign-in scopes',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/documents', 'https://www.googleapis.com/auth/forms.body', 'https://www.googleapis.com/auth/drive.file'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/documents',
#    'https://www.googleapis.com/auth/forms.body',
#    'https://www.googleapis.com/auth/drive.file'],
#   False,
#   'Online authentication with basic profile info, full access to create and edit Google Docs and Forms, and access to Drive file',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/firebase', 'https://www.googleapis.com/auth/fitness.blood_glucose.read'],True": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/firebase',
#    'https://www.googleapis.com/auth/fitness.blood_glucose.read'],
#   True,
#   'Authentication with profile info, full offline access to firebase and blood glucose levels.',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/gmail.readonly', 'https://www.googleapis.com/auth/calendar.events.owned'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/gmail.readonly',
#    'https://www.googleapis.com/auth/calendar.events.owned'],
#   False,
#   'Authentication, read only for gmail and full access to owned calendars',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/classroom.coursework.students', 'https://www.googleapis.com/auth/spreadsheets'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/classroom.coursework.students',
#    'https://www.googleapis.com/auth/spreadsheets'],
#   False,
#   'Authentication, access to coursework and grades for students in your classrooms and full access to Google Sheets.',
#   'Student Created'),
#  "['https://www.googleapis.com/auth/bigquery.insertdata', 'https://www.googleapis.com/auth/drive.readonly'],False": (['https://www.googleapis.com/auth/bigquery.insertdata',
#    'https://www.googleapis.com/auth/drive.readonly'],
#   False,
#   'Access to inserting data into BigQuery and access to see and download all Google Drive files.',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/drive.readonly', 'https://www.googleapis.com/auth/youtube.upload'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/drive.readonly',
#    'https://www.googleapis.com/auth/youtube.upload'],
#   False,
#   'Online authentication media uploader to YouTube with full download access to Drive',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/forms.responses.readonly', 'https://www.googleapis.com/auth/gmail.send'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/forms.responses.readonly',
#    'https://www.googleapis.com/auth/gmail.send'],
#   False,
#   'Online authentication with basic profile information that has read access to form responces and abillity to send gmail.',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/analytics.readonly', 'https://www.googleapis.com/auth/spreadsheets'],True": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/analytics.readonly',
#    'https://www.googleapis.com/auth/spreadsheets'],
#   True,
#   'Offline with read access to your Google Analytics and AdSense data and full access to Google Sheets',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/gmail.send', 'https://www.googleapis.com/auth/gmail.readonly', 'https://www.googleapis.com/auth/spreadsheets', 'https://www.googleapis.com/auth/drive.file', 'https://www.googleapis.com/auth/contacts.readonly'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/gmail.send',
#    'https://www.googleapis.com/auth/gmail.readonly',
#    'https://www.googleapis.com/auth/spreadsheets',
#    'https://www.googleapis.com/auth/drive.file',
#    'https://www.googleapis.com/auth/contacts.readonly'],
#   False,
#   'Online authentication and profile information with send/read permisons for gmail, read only for contacts, and full access to drive and spreadsheets.',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/blogger', 'https://www.googleapis.com/auth/documents.readonly'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/blogger',
#    'https://www.googleapis.com/auth/documents.readonly'],
#   False,
#   'Online read only access to Google Documents and full access to your Blogger account',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/drive.scripts', 'https://www.googleapis.com/auth/script.projects', 'https://www.googleapis.com/auth/drive.activity'],True": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/drive.scripts',
#    'https://www.googleapis.com/auth/script.projects',
#    'https://www.googleapis.com/auth/drive.activity'],
#   True,
#   'Authentication with offline access to modify your Google Drive App Scripts, Google App Scripts, and Google Drive Activity.',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/forms.responses.readonly', 'https://www.googleapis.com/auth/calendar.events.owned'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/forms.responses.readonly',
#    'https://www.googleapis.com/auth/calendar.events.owned'],
#   False,
#   'Online authentication, access to read only data coming from forms you own and full access to modify calendars you own.',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/gmail.addons.current.message.readonly', 'https://www.googleapis.com/auth/chat.messages'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/gmail.addons.current.message.readonly',
#    'https://www.googleapis.com/auth/chat.messages'],
#   False,
#   'Online authentication read only access to gmail and full access to Google Chat.',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/calendar.events.owned', 'https://www.googleapis.com/auth/chat.messages.readonly'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/calendar.events.owned',
#    'https://www.googleapis.com/auth/chat.messages.readonly'],
#   False,
#   'Online read only access to Google Chat messages and full access to modify s you own.',
#   'Student Created'),
#  "['https://www.googleapis.com/auth/bigquery', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/spreadsheets'],True": (['https://www.googleapis.com/auth/bigquery',
#    'https://www.googleapis.com/auth/devstorage.read_write',
#    'https://www.googleapis.com/auth/spreadsheets'],
#   True,
#   'Offline full access to BigQuery, read write access to Cloud Storage, and full access to Google Sheets.',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/gmail.send', 'https://www.googleapis.com/auth/admin.datatransfer'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/gmail.send',
#    'https://www.googleapis.com/auth/admin.datatransfer'],
#   False,
#   'Online authentication with ability to send Gmail notifications and access to view and manage data transfers between users in your organization.',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/drive.activity.readonly', 'https://www.googleapis.com/auth/gmail.send'],True": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/drive.activity.readonly',
#    'https://www.googleapis.com/auth/gmail.send'],
#   True,
#   'Offline access to read google drive activity and send mail via gmail on your behalf.',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/gmail.labels', 'https://www.googleapis.com/auth/gmail.metadata'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/gmail.labels',
#    'https://www.googleapis.com/auth/gmail.metadata'],
#   False,
#   'Online access to managing your email labels and read only access to email metadata.',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/compute.readonly', 'https://www.googleapis.com/auth/firebase.readonly', 'https://www.googleapis.com/auth/spreadsheets'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/compute.readonly',
#    'https://www.googleapis.com/auth/firebase.readonly',
#    'https://www.googleapis.com/auth/spreadsheets'],
#   False,
#   'Online read-only access to your Firebase data as well as Google Compute data and full access to Google Sheets.',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/firebase.readonly', 'https://www.googleapis.com/auth/analytics.readonly'],True": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/firebase.readonly',
#    'https://www.googleapis.com/auth/analytics.readonly'],
#   True,
#   'Offline read-only access to Google Firebase and Google Analytics data',
#   'Student Created'),
#  "['https://www.googleapis.com/auth/admin.directory.user.security', 'https://www.googleapis.com/auth/admin.directory.domain', 'https://www.googleapis.com/auth/admin.directory.rolemanagement', 'https://www.googleapis.com/auth/spreadsheets.readonly'],False": (['https://www.googleapis.com/auth/admin.directory.user.security',
#    'https://www.googleapis.com/auth/admin.directory.domain',
#    'https://www.googleapis.com/auth/admin.directory.rolemanagement',
#    'https://www.googleapis.com/auth/spreadsheets.readonly'],
#   False,
#   'Online read-only access to Google Sheets, access to provisioning of domains for users, role management, and data access permisions for users in your domain.',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/gmail.send', 'https://www.googleapis.com/auth/classroom.profile.emails', 'https://www.googleapis.com/auth/calendar.events.readonly'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/gmail.send',
#    'https://www.googleapis.com/auth/classroom.profile.emails',
#    'https://www.googleapis.com/auth/calendar.events.readonly'],
#   False,
#   'Online access send emails on your behalf, read only access to the emails of people in your classrooms, and read only access to all events on your Google Calendar.',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/groups', 'https://www.googleapis.com/auth/contacts.readonly'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/groups',
#    'https://www.googleapis.com/auth/contacts.readonly'],
#   False,
#   'Online full access to groups and read only access to your contacts.',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/adsense.readonly', 'https://www.googleapis.com/auth/analytics.readonly'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/adsense.readonly',
#    'https://www.googleapis.com/auth/analytics.readonly'],
#   False,
#   'Online read only access to AdSense data and Analytics',
#   'Student Created'),
#  "['openid', 'profile', 'email', 'https://www.googleapis.com/auth/photoslibrary.appendonly', 'https://www.googleapis.com/auth/chat.messages.readonly', 'https://www.googleapis.com/auth/gmail.addons.current.message.readonly'],False": (['openid',
#    'profile',
#    'email',
#    'https://www.googleapis.com/auth/photoslibrary.appendonly',
#    'https://www.googleapis.com/auth/chat.messages.readonly',
#    'https://www.googleapis.com/auth/gmail.addons.current.message.readonly'],
#   False,
#   'Online access to append to Google Photos library, read all Google Chat messages, and read Gmail messages when the add-on is active ',
#   'Student Created'),
#  "['https://mail.google.com/', 'https://www.googleapis.com/auth/drive', 'https://www.googleapis.com/auth/contacts'],True": (['https://mail.google.com/',
#    'https://www.googleapis.com/auth/drive',
#    'https://www.googleapis.com/auth/contacts'],
#   True,
#   'Full data exfiltration via consent phishing.',
#   'Published Attack Patterns'),
#  "['https://mail.google.com/', 'https://www.googleapis.com/auth/contacts', 'https://www.googleapis.com/auth/calendar'],True": (['https://mail.google.com/',
#    'https://www.googleapis.com/auth/contacts',
#    'https://www.googleapis.com/auth/calendar'],
#   True,
#   'Consent phishing targeting email, contacts, and calendar.',
#   'Published Attack Patterns'),
#  "['https://www.googleapis.com/auth/gmail.send', 'https://www.googleapis.com/auth/contacts.readonly'],True": (['https://www.googleapis.com/auth/gmail.send',
#    'https://www.googleapis.com/auth/contacts.readonly'],
#   True,
#   'Send-as phishing with contact harvesting.',
#   'Published Attack Patterns'),
#  "['https://mail.google.com/'],True": (['https://mail.google.com/'],
#   True,
#   'Full Gmail takeover via a single scope.',
#   'Published Attack Patterns'),
#  "['https://www.googleapis.com/auth/drive'],True": (['https://www.googleapis.com/auth/drive'],
#   True,
#   'Persistent Drive access via token abuse.',
#   'Published Attack Patterns'),
#  "['https://www.googleapis.com/auth/gmail.send', 'https://www.googleapis.com/auth/gmail.readonly', 'https://www.googleapis.com/auth/drive', 'https://www.googleapis.com/auth/contacts'],True": (['https://www.googleapis.com/auth/gmail.send',
#    'https://www.googleapis.com/auth/gmail.readonly',
#    'https://www.googleapis.com/auth/drive',
#    'https://www.googleapis.com/auth/contacts'],
#   True,
#   'Comprehensive spearphishing setup.',
#   'Published Attack Patterns'),
#  "['https://www.googleapis.com/auth/gmail.send', 'https://www.googleapis.com/auth/gmail.readonly', 'https://www.googleapis.com/auth/contacts.readonly'],True": (['https://www.googleapis.com/auth/gmail.send',
#    'https://www.googleapis.com/auth/gmail.readonly',
#    'https://www.googleapis.com/auth/contacts.readonly'],
#   True,
#   'Email impersonation setup.',
#   'Published Attack Patterns'),
#  "['https://mail.google.com/', 'https://www.googleapis.com/auth/gmail.settings.sharing'],True": (['https://mail.google.com/',
#    'https://www.googleapis.com/auth/gmail.settings.sharing'],
#   True,
#   'Full email access with forwarding rule injection.',
#   'Published Attack Patterns'),
#  "['https://www.googleapis.com/auth/gmail.modify', 'https://www.googleapis.com/auth/gmail.settings.basic'],True": (['https://www.googleapis.com/auth/gmail.modify',
#    'https://www.googleapis.com/auth/gmail.settings.basic'],
#   True,
#   'Email modification with filter manipulation.',
#   'Published Attack Patterns'),
#  "['https://www.googleapis.com/auth/admin.directory.user', 'https://www.googleapis.com/auth/admin.directory.user.security', 'https://www.googleapis.com/auth/admin.directory.rolemanagement'],True": (['https://www.googleapis.com/auth/admin.directory.user',
#    'https://www.googleapis.com/auth/admin.directory.user.security',
#    'https://www.googleapis.com/auth/admin.directory.rolemanagement'],
#   True,
#   'Admin account takeover.',
#   'Published Attack Patterns'),
#  "['https://www.googleapis.com/auth/cloud-platform', 'https://www.googleapis.com/auth/compute'],True": (['https://www.googleapis.com/auth/cloud-platform',
#    'https://www.googleapis.com/auth/compute'],
#   True,
#   'Cloud infrastructure compromise.',
#   'Published Attack Patterns'),
#  "['https://www.googleapis.com/auth/admin.directory.user', 'https://www.googleapis.com/auth/admin.directory.group', 'https://www.googleapis.com/auth/admin.directory.domain', 'https://www.googleapis.com/auth/admin.datatransfer'],True": (['https://www.googleapis.com/auth/admin.directory.user',
#    'https://www.googleapis.com/auth/admin.directory.group',
#    'https://www.googleapis.com/auth/admin.directory.domain',
#    'https://www.googleapis.com/auth/admin.datatransfer'],
#   True,
#   'Full domain admin compromise.',
#   'Published Attack Patterns'),
#  "['https://www.googleapis.com/auth/admin.directory.user', 'https://mail.google.com/'],True": (['https://www.googleapis.com/auth/admin.directory.user',
#    'https://mail.google.com/'],
#   True,
#   'Admin plus full email access enables user impersonation.',
#   'Published Attack Patterns'),
#  "['https://www.googleapis.com/auth/drive', 'https://www.googleapis.com/auth/documents', 'https://www.googleapis.com/auth/spreadsheets'],True": (['https://www.googleapis.com/auth/drive',
#    'https://www.googleapis.com/auth/documents',
#    'https://www.googleapis.com/auth/spreadsheets'],
#   True,
#   'Document exfiltration targeting all file types.',
#   'Published Attack Patterns'),
#  "['https://www.googleapis.com/auth/drive.readonly', 'https://www.googleapis.com/auth/gmail.readonly', 'https://www.googleapis.com/auth/calendar.acls.readonly', 'https://www.googleapis.com/auth/directory.readonly'],True": (['https://www.googleapis.com/auth/drive.readonly',
#    'https://www.googleapis.com/auth/gmail.readonly',
#    'https://www.googleapis.com/auth/calendar.acls.readonly',
#    'https://www.googleapis.com/auth/directory.readonly'],
#   True,
#   'Passive surveillance using read-only scopes.',
#   'Published Attack Patterns'),
#  "['https://www.googleapis.com/auth/photoslibrary', 'https://www.googleapis.com/auth/drive', 'https://www.googleapis.com/auth/contacts'],True": (['https://www.googleapis.com/auth/photoslibrary',
#    'https://www.googleapis.com/auth/drive',
#    'https://www.googleapis.com/auth/contacts'],
#   True,
#   'Personal data theft targeting photos, files, and contacts.',
#   'Published Attack Patterns'),
#  "['https://www.googleapis.com/auth/keep', 'https://www.googleapis.com/auth/drive', 'https://www.googleapis.com/auth/gmail.readonly'],True": (['https://www.googleapis.com/auth/keep',
#    'https://www.googleapis.com/auth/drive',
#    'https://www.googleapis.com/auth/gmail.readonly'],
#   True,
#   'Credential harvesting from notes and files.',
#   'Published Attack Patterns'),
#  "['https://www.googleapis.com/auth/fitness.blood_glucose.read', 'https://www.googleapis.com/auth/fitness.blood_pressure.read', 'https://www.googleapis.com/auth/fitness.heart_rate.read', 'https://www.googleapis.com/auth/fitness.body.read'],True": (['https://www.googleapis.com/auth/fitness.blood_glucose.read',
#    'https://www.googleapis.com/auth/fitness.blood_pressure.read',
#    'https://www.googleapis.com/auth/fitness.heart_rate.read',
#    'https://www.googleapis.com/auth/fitness.body.read'],
#   True,
#   'Health data theft from Google Fitness. Medical data including blood glucose, blood pressure, heart rate, and body measurements is highly sensitive and subject to health privacy regulations.',
#   'Published Attack Patterns'),
#  "['https://mail.google.com/', 'https://www.googleapis.com/auth/drive', 'https://www.googleapis.com/auth/calendar', 'https://www.googleapis.com/auth/contacts', 'https://www.googleapis.com/auth/tasks', 'https://www.googleapis.com/auth/keep'],True": (['https://mail.google.com/',
#    'https://www.googleapis.com/auth/drive',
#    'https://www.googleapis.com/auth/calendar',
#    'https://www.googleapis.com/auth/contacts',
#    'https://www.googleapis.com/auth/tasks',
#    'https://www.googleapis.com/auth/keep'],
#   True,
#   'Massively over-privileged app requesting access to six distinct services.',
#   'Published Attack Patterns'),
#  "['https://www.googleapis.com/auth/cloud-platform', 'https://mail.google.com/', 'https://www.googleapis.com/auth/drive', 'https://www.googleapis.com/auth/admin.directory.user'],True": (['https://www.googleapis.com/auth/cloud-platform',
#    'https://mail.google.com/',
#    'https://www.googleapis.com/auth/drive',
#    'https://www.googleapis.com/auth/admin.directory.user'],
#   True,
#   'Maximum privilege request spanning cloud infrastructure, email, files, and user administration',
#   'Published Attack Patterns'),
#  "['https://www.googleapis.com/auth/gmail.modify', 'https://www.googleapis.com/auth/drive', 'https://www.googleapis.com/auth/calendar', 'https://www.googleapis.com/auth/contacts', 'https://www.googleapis.com/auth/youtube', 'https://www.googleapis.com/auth/photoslibrary'],True": (['https://www.googleapis.com/auth/gmail.modify',
#    'https://www.googleapis.com/auth/drive',
#    'https://www.googleapis.com/auth/calendar',
#    'https://www.googleapis.com/auth/contacts',
#    'https://www.googleapis.com/auth/youtube',
#    'https://www.googleapis.com/auth/photoslibrary'],
#   True,
#   'Kitchen-sink scope request spanning six unrelated services.',
#   'Published Attack Patterns'),
#  "['https://mail.google.com/', 'https://www.googleapis.com/auth/directory.readonly'],True": (['https://mail.google.com/',
#    'https://www.googleapis.com/auth/directory.readonly'],
#   True,
#   'A desktop email client requires full mailbox access to display, compose, and delete emails',
#   'Github Manifest Combinations'),
#  "['https://www.googleapis.com/auth/gmail.modify', 'https://www.googleapis.com/auth/gmail.labels', 'https://www.googleapis.com/auth/contacts.other.readonly'],True": (['https://www.googleapis.com/auth/gmail.modify',
#    'https://www.googleapis.com/auth/gmail.labels',
#    'https://www.googleapis.com/auth/contacts.other.readonly'],
#   True,
#   'Webmail managers need to read and modify emails (move, archive, label) and manage labels for folder-like organization.',
#   'Github Manifest Combinations'),
#  "['https://www.googleapis.com/auth/gmail.readonly', 'https://www.googleapis.com/auth/gmail.send', 'https://www.googleapis.com/auth/gmail.compose'],True": (['https://www.googleapis.com/auth/gmail.readonly',
#    'https://www.googleapis.com/auth/gmail.send',
#    'https://www.googleapis.com/auth/gmail.compose'],
#   True,
#   'A helpdesk reads incoming support emails, drafts responses using templates, and sends replies.',
#   'Github Manifest Combinations'),
#  "['https://www.googleapis.com/auth/gmail.send', 'https://www.googleapis.com/auth/gmail.readonly', 'https://www.googleapis.com/auth/contacts.readonly', 'https://www.googleapis.com/auth/calendar.events'],True": (['https://www.googleapis.com/auth/gmail.send',
#    'https://www.googleapis.com/auth/gmail.readonly',
#    'https://www.googleapis.com/auth/contacts.readonly',
#    'https://www.googleapis.com/auth/calendar.events'],
#   True,
#   'A CRM reads emails to log conversation history, sends outreach emails, reads contacts to build the lead database, and accesses calendar events to track meetings.',
#   'Github Manifest Combinations'),
#  "['https://www.googleapis.com/auth/contacts', 'https://www.googleapis.com/auth/gmail.send', 'https://www.googleapis.com/auth/calendar.events', 'https://www.googleapis.com/auth/drive.file'],True": (['https://www.googleapis.com/auth/contacts',
#    'https://www.googleapis.com/auth/gmail.send',
#    'https://www.googleapis.com/auth/calendar.events',
#    'https://www.googleapis.com/auth/drive.file'],
#   True,
#   'Sales platforms need write access to contacts, email sending, calendar access, and app-specific Drive access.',
#   'Github Manifest Combinations'),
#  "['https://www.googleapis.com/auth/gmail.readonly', 'https://www.googleapis.com/auth/contacts.readonly', 'https://www.googleapis.com/auth/calendar.calendars.readonly'],True": (['https://www.googleapis.com/auth/gmail.readonly',
#    'https://www.googleapis.com/auth/contacts.readonly',
#    'https://www.googleapis.com/auth/calendar.calendars.readonly'],
#   True,
#   "A read-only CRM sync only ingests data without modifying the user's account",
#   'Github Manifest Combinations'),
#  "['https://www.googleapis.com/auth/calendar.events', 'https://www.googleapis.com/auth/tasks', 'https://www.googleapis.com/auth/drive.file'],False": (['https://www.googleapis.com/auth/calendar.events',
#    'https://www.googleapis.com/auth/tasks',
#    'https://www.googleapis.com/auth/drive.file'],
#   False,
#   'A project management tool syncs calendar events to show deadlines on a project timeline, syncs tasks for to-do tracking, and attaches files from Drive to cards or tickets.',
#   'Github Manifest Combinations'),
#  "['https://www.googleapis.com/auth/drive.file', 'https://www.googleapis.com/auth/spreadsheets'],False": (['https://www.googleapis.com/auth/drive.file',
#    'https://www.googleapis.com/auth/spreadsheets'],
#   False,
#   'Some open-source tools store their board state in a Google Sheet rather than a dedicated database',
#   'Github Manifest Combinations'),
#  "['https://www.googleapis.com/auth/calendar.events.readonly', 'https://www.googleapis.com/auth/tasks.readonly'],False": (['https://www.googleapis.com/auth/calendar.events.readonly',
#    'https://www.googleapis.com/auth/tasks.readonly'],
#   False,
#   "Time trackers only need to observe the user's calendar and tasks to log time automatically.",
#   'Github Manifest Combinations'),
#  "['https://mail.google.com/', 'https://www.googleapis.com/auth/drive', 'https://www.googleapis.com/auth/calendar', 'https://www.googleapis.com/auth/contacts'],True": (['https://mail.google.com/',
#    'https://www.googleapis.com/auth/drive',
#    'https://www.googleapis.com/auth/calendar',
#    'https://www.googleapis.com/auth/contacts'],
#   True,
#   "A backup tool must access the user's complete data across all services.",
#   'Github Manifest Combinations'),
#  "['https://www.googleapis.com/auth/drive', 'https://www.googleapis.com/auth/calendar', 'https://www.googleapis.com/auth/spreadsheets'],True": (['https://www.googleapis.com/auth/drive',
#    'https://www.googleapis.com/auth/calendar',
#    'https://www.googleapis.com/auth/spreadsheets'],
#   True,
#   'Migration tools need full Drive access plus explicit Docs and Sheets scopes to preserve native document formatting during cross-platform transfers.',
#   'Github Manifest Combinations'),
#  "['https://www.googleapis.com/auth/gmail.readonly', 'https://www.googleapis.com/auth/drive.readonly'],True": (['https://www.googleapis.com/auth/gmail.readonly',
#    'https://www.googleapis.com/auth/drive.readonly'],
#   True,
#   'An email archiver reads all mail and optionally reads Drive attachments for a complete archive.',
#   'Github Manifest Combinations'),
#  "['https://www.googleapis.com/auth/spreadsheets', 'https://www.googleapis.com/auth/gmail.send', 'https://www.googleapis.com/auth/drive.file'],False": (['https://www.googleapis.com/auth/spreadsheets',
#    'https://www.googleapis.com/auth/gmail.send',
#    'https://www.googleapis.com/auth/drive.file'],
#   False,
#   'A mail merge reads recipient lists from a spreadsheet, sends personalized emails, and accesses Drive for email template files.',
#   'Github Manifest Combinations'),
#  "['https://www.googleapis.com/auth/spreadsheets', 'https://www.googleapis.com/auth/gmail.send', 'https://www.googleapis.com/auth/contacts.readonly'],False": (['https://www.googleapis.com/auth/spreadsheets',
#    'https://www.googleapis.com/auth/gmail.send',
#    'https://www.googleapis.com/auth/contacts.readonly'],
#   False,
#   'Similar to mail merge but uses contacts for recipient data instead of or in addition to a spreadsheet.',
#   'Github Manifest Combinations'),
#  "['https://www.googleapis.com/auth/script.projects', 'https://www.googleapis.com/auth/drive', 'https://www.googleapis.com/auth/spreadsheets', 'https://www.googleapis.com/auth/gmail.send'],True": (['https://www.googleapis.com/auth/script.projects',
#    'https://www.googleapis.com/auth/drive',
#    'https://www.googleapis.com/auth/spreadsheets',
#    'https://www.googleapis.com/auth/gmail.send'],
#   True,
#   'General-purpose automation platforms need broad access because they execute user-defined workflows that may span multiple services',
#   'Github Manifest Combinations'),
#  "['https://www.googleapis.com/auth/forms.body', 'https://www.googleapis.com/auth/forms.responses.readonly', 'https://www.googleapis.com/auth/spreadsheets', 'https://www.googleapis.com/auth/gmail.send'],False": (['https://www.googleapis.com/auth/forms.body',
#    'https://www.googleapis.com/auth/forms.responses.readonly',
#    'https://www.googleapis.com/auth/spreadsheets',
#    'https://www.googleapis.com/auth/gmail.send'],
#   False,
#   'A form auto-responder watches for new form submissions, logs responses to a spreadsheet for record-keeping, and sends a confirmation email to each respondent.',
#   'Github Manifest Combinations'),
#  "['https://www.googleapis.com/auth/analytics.readonly', 'https://www.googleapis.com/auth/spreadsheets'],False": (['https://www.googleapis.com/auth/analytics.readonly',
#    'https://www.googleapis.com/auth/spreadsheets'],
#   False,
#   'These tools pull Google Analytics data and write it to a spreadsheet for custom dashboarding.',
#   'Github Manifest Combinations'),
#  "['https://www.googleapis.com/auth/analytics', 'https://www.googleapis.com/auth/bigquery'],False": (['https://www.googleapis.com/auth/analytics',
#    'https://www.googleapis.com/auth/bigquery'],
#   False,
#   'For large-scale analytics, data is piped from Google Analytics into BigQuery for SQL-based analysis.',
#   'Github Manifest Combinations'),
#  "['https://www.googleapis.com/auth/admin.directory.user.readonly', 'https://www.googleapis.com/auth/spreadsheets'],False": (['https://www.googleapis.com/auth/admin.directory.user.readonly',
#    'https://www.googleapis.com/auth/spreadsheets'],
#   False,
#   'Security teams export Workspace audit logs to spreadsheets for compliance reporting.',
#   'Github Manifest Combinations'),
#  "['https://www.googleapis.com/auth/youtube.upload', 'https://www.googleapis.com/auth/drive.readonly'],False": (['https://www.googleapis.com/auth/youtube.upload',
#    'https://www.googleapis.com/auth/drive.readonly'],
#   False,
#   'These tools read video files from Drive and upload them to YouTube on a schedule.',
#   'Github Manifest Combinations'),
#  "['https://www.googleapis.com/auth/youtube', 'https://www.googleapis.com/auth/analytics.readonly'],True": (['https://www.googleapis.com/auth/youtube',
#    'https://www.googleapis.com/auth/analytics.readonly'],
#   True,
#   'Creator dashboards need full YouTube access for channel management plus analytics for performance metrics.',
#   'Github Manifest Combinations'),
#  "['https://www.googleapis.com/auth/photoslibrary', 'https://www.googleapis.com/auth/drive'],True": (['https://www.googleapis.com/auth/photoslibrary',
#    'https://www.googleapis.com/auth/drive'],
#   True,
#   'Photo organizers sync between Google Photos and Drive folders, requiring full access to both services.',
#   'Github Manifest Combinations'),
#  "['https://www.googleapis.com/auth/classroom.courses', 'https://www.googleapis.com/auth/classroom.rosters', 'https://www.googleapis.com/auth/drive.file', 'https://www.googleapis.com/auth/forms.body'],False": (['https://www.googleapis.com/auth/classroom.courses',
#    'https://www.googleapis.com/auth/classroom.rosters',
#    'https://www.googleapis.com/auth/drive.file',
#    'https://www.googleapis.com/auth/forms.body'],
#   False,
#   'A learning management system integration needs to read and create courses, access class rosters for enrollment sync, attach files to assignments via Drive, and create quizzes via Forms.',
#   'Github Manifest Combinations'),
#  "['https://www.googleapis.com/auth/classroom.coursework.students', 'https://www.googleapis.com/auth/spreadsheets', 'https://www.googleapis.com/auth/gmail.send'],False": (['https://www.googleapis.com/auth/classroom.coursework.students',
#    'https://www.googleapis.com/auth/spreadsheets',
#    'https://www.googleapis.com/auth/gmail.send'],
#   False,
#   'A grade notification tool reads student coursework and grades, exports them to a spreadsheet for record-keeping, and sends email notifications to students or parents.',
#   'Github Manifest Combinations'),
#  "['https://www.googleapis.com/auth/chat.messages', 'https://www.googleapis.com/auth/chat.spaces', 'https://www.googleapis.com/auth/calendar.events.readonly'],False": (['https://www.googleapis.com/auth/chat.messages',
#    'https://www.googleapis.com/auth/chat.spaces',
#    'https://www.googleapis.com/auth/calendar.events.readonly'],
#   False,
#   'A reminder bot reads upcoming calendar events and sends notification messages into Chat spaces.',
#   'Github Manifest Combinations'),
#  "['https://www.googleapis.com/auth/chat.messages', 'https://www.googleapis.com/auth/drive.readonly'],False": (['https://www.googleapis.com/auth/chat.messages',
#    'https://www.googleapis.com/auth/drive.readonly'],
#   False,
#   'A file sharing bot allows users to search and share Drive files directly within Chat.',
#   'Github Manifest Combinations'),
#  "['openid', 'email', 'profile'],False": (['openid', 'email', 'profile'],
#   False,
#   'The minimal sign-in scope set used by virtually every web application offering Google SSO.',
#   'Github Manifest Combinations'),
#  "['openid', 'email', 'https://www.googleapis.com/auth/userinfo.email', 'https://www.googleapis.com/auth/userinfo.profile'],False": (['openid',
#    'email',
#    'https://www.googleapis.com/auth/userinfo.email',
#    'https://www.googleapis.com/auth/userinfo.profile'],
#   False,
#   'Some OAuth libraries request the explicit userinfo scopes alongside the shorthand scopes.',
#   'Github Manifest Combinations'),
#  "['https://www.googleapis.com/auth/admin.directory.user', 'https://www.googleapis.com/auth/admin.directory.group', 'https://www.googleapis.com/auth/admin.directory.user.security'],True": (['https://www.googleapis.com/auth/admin.directory.user',
#    'https://www.googleapis.com/auth/admin.directory.group',
#    'https://www.googleapis.com/auth/admin.directory.user.security'],
#   True,
#   'IT admin tools manage user accounts, group memberships, and security settings.',
#   'Github Manifest Combinations'),
#  "['https://www.googleapis.com/auth/admin.directory.user.readonly', 'https://www.googleapis.com/auth/admin.reports.audit.readonly'],False": (['https://www.googleapis.com/auth/admin.directory.user.readonly',
#    'https://www.googleapis.com/auth/admin.reports.audit.readonly'],
#   False,
#   'Security dashboards need read-only access to the user directory (to identify accounts) and audit logs. ',
#   'Github Manifest Combinations'),
#  "['https://www.googleapis.com/auth/admin.directory.user', 'https://www.googleapis.com/auth/admin.datatransfer', 'https://www.googleapis.com/auth/admin.directory.domain'],True": (['https://www.googleapis.com/auth/admin.directory.user',
#    'https://www.googleapis.com/auth/admin.datatransfer',
#    'https://www.googleapis.com/auth/admin.directory.domain'],
#   True,
#   'Domain migration requires user management (to recreate accounts), data transfer, and domain provisioning.',
#   'Github Manifest Combinations'),
#  "['https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/bigquery'],False": (['https://www.googleapis.com/auth/devstorage.read_write',
#    'https://www.googleapis.com/auth/bigquery'],
#   False,
#   'Data pipelines move data between Cloud Storage and BigQuery. ',
#   'Github Manifest Combinations'),
#  "['https://www.googleapis.com/auth/cloud-platform.read-only', 'https://www.googleapis.com/auth/compute.readonly'],False": (['https://www.googleapis.com/auth/cloud-platform.read-only',
#    'https://www.googleapis.com/auth/compute.readonly'],
#   False,
#   '',
#   'Github Manifest Combinations')}

# %%
#As you can see I use deep copy, after roughly an hour of questioning my existance
#I found out that copy, and just doing a = b, still shares memory adresses of nested
#lists, or tuples in our case. This one fact was causing so much trouble with the code
#and bassically was making loops go on indefintely, or create blank scope lists.
#So yeah, deep copy is 100% nessescary for this.
base_scope_combos = copy.deepcopy(all_scope_combinations)
github_copy = copy.deepcopy(github_manifest_combinations)
student_copy = copy.deepcopy(student_created_scope_combinations)
len(base_scope_combos)
# Out:
# 104

# %%
#Boolean Switching: Strategy A
for scope_combo in base_scope_combos:
  #creating a new scope combo and setting orginal_combo to True
  original_combo = True
  new_scope_combo = (scope_combo[0], not scope_combo[1],'','Strategy A: Boolean Switching')

  #checking if the scope is orgiginal by comparing it to the keys of scope_dict
  if dict_dupe_validation(scope_dict,new_scope_combo):
    all_scope_combinations.append(new_scope_combo)

    #we use dict to validate, so have to add new addition to dict if valid
    scope_dict[f'{new_scope_combo[0]},{new_scope_combo[1]}'] = new_scope_combo


len(all_scope_combinations)
# Out:
# 208

# %%
commonly_requested_scopes = ['https://www.googleapis.com/auth/gmail.send',
                             'https://www.googleapis.com/auth/contacts.readonly',
                             'https://www.googleapis.com/auth/drive.file',
                             'https://www.googleapis.com/auth/calendar.events.readonly',
                             'https://www.googleapis.com/auth/tasks',
                             'https://www.googleapis.com/auth/spreadsheets',
                             'https://www.googleapis.com/auth/chat.messages',
                             'email',
                             'profile',
                             'https://www.googleapis.com/auth/fitness.activity.read',
                             'openid'
                             ]
#I made the choice to add email, profile, and openid to this.
#This does have some downsides as a lot of scopes include them already.

# %%
#Random Scope Addition: Strategy B, github
num_overflows = 0 # way to see how many overflows we are hitting

random.seed(RANDOM_SEED)
for idx, scope_combo in enumerate(github_copy):
  past_random = []
  for i in range(3):
    random_scope = commonly_requested_scopes[random.randint(0,len(commonly_requested_scopes)-1)]

    #if it generated a duplicate or a scope in the scope list already it
    #keeps on going. overflow stops the code if the while loop continues for too
    #long meaining a valid addition isn't possible. 22 is kind of an artibitary
    #choice for a cutoff, but it's twice the len of common scopes so if there
    #is a valid combo is should be found before then.
    overflow = 0
    while random_scope in past_random or random_scope in scope_combo[0]:
      random_scope = commonly_requested_scopes[random.randint(0,len(commonly_requested_scopes)-1)]
      overflow +=1
      if overflow >= 22:
        break

    #overflow check to break the loop if a valid addition wasn't found
    if overflow >= 22:
      num_overflows +=1
      print(f'GITHUB OVERFLOW reached {num_overflows} IDX: {idx}')
      continue

    past_random.append(random_scope) #adding scope to past random

    new_scope_list = scope_combo[0] + [random_scope]
    new_scope_combo = (new_scope_list, scope_combo[1], '','Strategy B: Addition (github manifest)')

    #checking if new addition would be orgiginal
    #if so, it's added
    if dict_dupe_validation(scope_dict,new_scope_combo):
      all_scope_combinations.append(new_scope_combo)

      #we use dict to validate, so have to add new addition to dict if valid
      scope_dict[f'{new_scope_combo[0]},{new_scope_combo[1]}'] = new_scope_combo

#Random Scope Addition: Strategy B, student gen
for idx, scope_combo in enumerate(student_copy):
  past_random = []
  for i in range(3):
    random_scope = commonly_requested_scopes[random.randint(0,len(commonly_requested_scopes)-1)]

    #if it generated a duplicate or a scope in the scope list already it
    #keeps on going. overflow stops the code if the while loop continues for too
    #long meaining a valid addition isn't possible. 22 is kind of an artibitary
    #choice for a cutoff, but it's twice the len of common scopes so if there
    #is a valid combo is should be found before then.
    overflow = 0
    while random_scope in past_random or random_scope in scope_combo[0]:
      random_scope = commonly_requested_scopes[random.randint(0,len(commonly_requested_scopes)-1)]
      overflow += 1
      if overflow >= 22:
        break

    past_random.append(random_scope) #adding scope to past random

    #overflow check to break the loop if a valid addition wasn't found
    if overflow >= 22:
      num_overflows +=1
      print(f'STUDENT OVERFLOW reached {num_overflows} IDX: {idx}')
      continue

    new_scope_list = scope_combo[0] + [random_scope]
    new_scope_combo = (new_scope_list, scope_combo[1], '','Strategy B: Addition (student_gen)')

    #checking if new addition would be orgiginal
    #if so, it's added
    if dict_dupe_validation(scope_dict,new_scope_combo):
      all_scope_combinations.append(new_scope_combo)

      #we use dict to validate, so have to add new addition to dict if valid
      scope_dict[f'{new_scope_combo[0]},{new_scope_combo[1]}'] = new_scope_combo

# %%
#Removal of random scope: Strategy B
random.seed(RANDOM_SEED)
for scope_combo in base_scope_combos:
  #checking if len of scope combinations is < 4, if so we skip itteration
  if (len(scope_combo[0]) < 4):
      continue

  scopes_removed_idx = []
  for i in range(4):
    rand_index = random.randint(0,len(scope_combo[0])-1)
    new_scope_list = copy.deepcopy(scope_combo[0])
    new_bool = copy.deepcopy(scope_combo[1])

    #generating a new number if we already removed that index
    while rand_index in scopes_removed_idx:
      rand_index = random.randint(0,len(new_scope_list)-1)

    scopes_removed_idx.append(rand_index)
    #deleting generated index
    del new_scope_list[rand_index]

    #creating new combo:
    new_scope_combo = (new_scope_list, new_bool, '','Strategy C: Removal')
    #checking if new addition would be orgiginal
    #if so, it's added
    if dict_dupe_validation(scope_dict,new_scope_combo):
      all_scope_combinations.append(new_scope_combo)

      #we use dict to validate, so have to add new addition to dict if valid
      scope_dict[f'{new_scope_combo[0]},{new_scope_combo[1]}'] = new_scope_combo
print(len(all_scope_combinations))
# Out:
# 668

# %%
#random within scope combinations
random.seed(RANDOM_SEED)
for service in SCOPES_BY_SERVICE:
  #getting number of scopes in a service
  num_scopes = len(SCOPES_BY_SERVICE[service])

  #we only add a new combo if their is more than 2 scopes in a service
  if num_scopes > 2:
    new_scope_list = []

    for i in range(3):
      new_scope = random.choice(SCOPES_BY_SERVICE[service])

      #ensuring no duplicates:
      while new_scope in new_scope_list:
        new_scope = random.choice(SCOPES_BY_SERVICE[service])

      #adding scope to list
      new_scope_list.append(new_scope)

  bools = [True,False]
  new_bool = random.choice(bools)

  #creating new combo:
  new_scope_combo = (new_scope_list, new_bool, '','Strategy D: Within Service Combinations')

  #checking if new addition would be original
  #if so, it's added
  if dict_dupe_validation(scope_dict,new_scope_combo):
    all_scope_combinations.append(new_scope_combo)

    #we use dict to validate, so have to add new addition to dict if valid
    scope_dict[f'{new_scope_combo[0]},{new_scope_combo[1]}'] = new_scope_combo
len(all_scope_combinations)
# Out:
# 688

# %%
plausable_cross_patterns = [
    ['Admin','Gmail'],
    ['Admin','Contacts'],
    ['Admin','Drive'],
    ['Admin','Apps Script'],
    ['Admin','Sheets'],
    ['Admin','Firebase'],
    ['Admin','Classroom'],
    ['Admin','Cloud'],
    ['Admin','BigQuery'],
    ['Admin','Compute'],
    ['Admin','Identity'],
    ['Gmail','Contacts'],
    ['Gmail','Drive'],
    ['Gmail','Photos'],
    ['Gmail','Docs'],
    ['Gmail','Sheets'],
    ['Gmail','Apps Script'],
    ['Gmail','Firebase'],
    ['Gmail','YouTube'],
    ['Gmail','Forms'],
    ['Gmail','Classroom'],
    ['Gmail','Calendar'],
    ['Gmail','Cloud'],
    ['Gmail','BigQuery'],
    ['Gmail','Compute'],
    ['Gmail','Blogger'],
    ['Gmail','AdSense'],
    ['Gmail','Identity'],
    ['Contacts','Keep'],
    ['Contacts','Chat'],
    ['Contacts','Drive'],
    ['Contacts','Photos'],
    ['Contacts','Docs'],
    ['Contacts','Sheets'],
    ['Contacts','Groups'],
    ['Contacts','Apps Script'],
    ['Contacts','Firebase'],
    ['Contacts','Forms'],
    ['Contacts','Cloud'],
    ['Contacts','Tasks'],
    ['Contacts','Classroom'],
    ['Contacts','Calendar'],
    ['Contacts','Identity'],
    ['Keep','Chat'],
    ['Keep','Fitness'],
    ['Keep','Drive'],
    ['Keep','Docs'],
    ['Keep','Sheets'],
    ['Keep','Groups'],
    ['Keep','Calendar'],
    ['Keep','Tasks'],
    ['Keep','Identity'],
    ['Chat','Drive'],
    ['Chat','Docs'],
    ['Chat','Photos'],
    ['Chat','Sheets'],
    ['Chat','Groups'],
    ['Chat','Apps Script'],
    ['Chat','Forms'],
    ['Chat','Classroom'],
    ['Chat','Tasks'],
    ['Chat','Calendar'],
    ['Chat','Identity'],
    ['Fitness','Drive'],
    ['Fitness','Photos'],
    ['Fitness','Sheets'],
    ['Fitness','Apps Script'],
    ['Fitness','Forms'],
    ['Fitness','Identity'],
    ['Drive','Photos'],
    ['Drive','Docs'],
    ['Drive','Sheets'],
    ['Drive','Apps Script'],
    ['Drive','Firebase'],
    ['Drive','YouTube'],
    ['Drive','Slides'],
    ['Drive','Forms'],
    ['Drive','Classroom'],
    ['Drive','Cloud'],
    ['Drive','BigQuery'],
    ['Drive','Compute'],
    ['Drive','Blogger'],
    ['Drive','Analytics'],
    ['Drive','Cloud Storage'],
    ['Drive','Identity'],
    ['Photos','Docs'],
    ['Photos','Apps Script'],
    ['Photos','Firebase'],
    ['Photos','YouTube'],
    ['Photos','Slides'],
    ['Photos','Tasks'],
    ['Photos','Blogger'],
    ['Photos','Identity'],
    ['Docs','Sheets'],
    ['Docs','Apps Script'],
    ['Docs','YouTube'],
    ['Docs','Slides'],
    ['Docs','Forms'],
    ['Docs','Classroom'],
    ['Docs','Calendar'],
    ['Docs','Tasks'],
    ['Docs','Cloud'],
    ['Docs','BigQuery'],
    ['Docs','AdSense'],
    ['Docs','Identity'],
    ['Sheets','Apps Script'],
    ['Sheets','Firebase'],
    ['Sheets','YouTube'],
    ['Sheets','Slides'],
    ['Sheets','Forms'],
    ['Sheets','Classroom'],
    ['Sheets','Calendar'],
    ['Sheets','Tasks'],
    ['Sheets','Cloud'],
    ['Sheets','BigQuery'],
    ['Sheets','Compute'],
    ['Sheets','AdSense'],
    ['Sheets','Analytics'],
    ['Sheets','Cloud Storage'],
    ['Sheets','Identity'],
    ['Groups','Apps Script'],
    ['Apps Script','Firebase'],
    ['Apps Script','YouTube'],
    ['Apps Script','Classroom'],
    ['Apps Script','Calendar'],
    ['Apps Script','Tasks'],
    ['Apps Script','Cloud'],
    ['Apps Script','BigQuery'],
    ['Apps Script','Compute'],
    ['Apps Script','Blogger'],
    ['Apps Script','AdSense'],
    ['Apps Script','Analytics'],
    ['Apps Script','Cloud Storage'],
    ['Firebase','YouTube'],
    ['Firebase','Forms'],
    ['Firebase','Cloud'],
    ['Firebase','BigQuery'],
    ['Firebase','Compute'],
    ['Firebase','AdSense'],
    ['Firebase','Analytics'],
    ['Firebase','Cloud Storage'],
    ['Firebase','Identity'],
    ['YouTube','Calendar'],
    ['YouTube','Tasks'],
    ['YouTube','Cloud'],
    ['YouTube','AdSense'],
    ['YouTube','Identity'],
    ['Slides','Classroom'],
    ['Forms','Classroom'],
    ['Forms','Cloud'],
    ['Forms','BigQuery'],
    ['Forms','Identity'],
    ['Classroom','Calendar'],
    ['Classroom','Tasks'],
    ['Classroom','Cloud'],
    ['Classroom','Identity'],
    ['Calendar','Tasks'],
    ['Calendar','Identity'],
    ['Tasks','Identity'],
    ['Cloud','BigQuery'],
    ['Cloud','Compute'],
    ['Cloud','AdSense'],
    ['Cloud','Analytics'],
    ['Cloud','Cloud Storage'],
    ['Cloud','Identity'],
    ['BigQuery','Compute'],
    ['BigQuery','AdSense'],
    ['BigQuery','Analytics'],
    ['BigQuery','Cloud Storage'],
    ['Compute','Cloud Storage'],
    ['Blogger','Analytics'],
    ['Blogger','Identity'],
    ['AdSense','Analytics'],
    ['AdSense','Cloud Storage'],
    ['AdSense', 'Identity'],
    ['Cloud Storage','Analytics']
]
len(plausable_cross_patterns)
# Out:
# 176

# %%
#Realistic cross patterns scope combo generation: Strategy E
random.seed(RANDOM_SEED)
for service_combo in plausable_cross_patterns:
  new_scope_list = []
  for service in service_combo:
    #selecting a random idx to choose a random scope from a service
    rand_idx = random.randint(0,len(SCOPES_BY_SERVICE[service])-1)
    #adding the scope at said random index to our scope list
    new_scope_list.append(SCOPES_BY_SERVICE[service][rand_idx])

  #we randomly choose a new offline/online bool
  bools = [True,False]
  new_bool = random.choice(bools)

  #creating new combo:
  new_scope_combo = (new_scope_list, new_bool, '','Strategy E: Plausable Cross Scope Combinations')

  #checking if new addition would be original
  #if so, it's added
  if dict_dupe_validation(scope_dict,new_scope_combo):
    all_scope_combinations.append(new_scope_combo)

    #we use dict to validate, so have to add new addition to dict if valid
    scope_dict[f'{new_scope_combo[0]},{new_scope_combo[1]}'] = new_scope_combo

# %%
#adding randomly generated scopes until we reach our goal of 1000 scope combos
#strategy f
random.seed(RANDOM_SEED)
while len(all_scope_combinations) < 1000:
  #choosing between 3 and 5 scopes to add:
  num_scopes = random.randint(3,5)
  #keeping track of scopes already added for the new_scope_combo
  scope_list = []

  #looping through and grabbing a random idx that coresponds to a random scope
  for i in range(num_scopes):
    #generating a random idx
    rand_idx = random.randint(0,len(ALL_SCOPES)-1)
    #mapping idx to scope
    new_scope = ALL_SCOPES[rand_idx]

    #ensuring that generated scope hasn't already been used by this combo
    while new_scope in scope_list:
      rand_idx = random.randint(0,len(ALL_SCOPES)-1)
      new_scope = ALL_SCOPES[rand_idx]

    #adding new scope to scopes already added list for this new combo
    scope_list.append(new_scope)

  #generating random online/offline bool:
  bools = [True,False]
  new_bool = random.choice(bools)

  #creating new combo
  new_scope_combo = (scope_list,new_bool,'','Strategy F: Randomly Generated Scope Combinations')

  #checking if new addition would be original, if so it's added
  if dict_dupe_validation(scope_dict,new_scope_combo):
    all_scope_combinations.append(new_scope_combo)

    #we use dict to validate, so have to add new addition to dict if valid
    scope_dict[f'{new_scope_combo[0]},{new_scope_combo[1]}'] = new_scope_combo
len(all_scope_combinations)
# Out:
# 1000

# %%
len(all_scope_combinations)
# Out:
# 1000

# %%
#adding randomly generated scopes to plausable combos to hit over 1000 scope
#combinations. strategy G.
random.seed(RANDOM_SEED)

#looping through every plausable service combination
for service_combo in plausable_cross_patterns:
  #creating a list to store all scopes generated for current service combo:
  new_scope_list = []
  #itterating over each serice (2) in a service combo
  for service in service_combo:

    #desciding whether or not to choose 1 or 2 scopes per service
    if len(SCOPES_BY_SERVICE[service]) == 1:
      scopes_to_select = 1
    else:
      scopes_to_select = random.randint(1,2)

    #selecting random scope(s) from current service:
    for i in range(scopes_to_select):
      #selecting random idx
      random_idx = random.randint(0,len(SCOPES_BY_SERVICE[service]) -1)

      #ensuring no duplicates are selected:
      while SCOPES_BY_SERVICE[service][random_idx] in new_scope_list:
        random_idx = random.randint(0,len(SCOPES_BY_SERVICE[service]) -1)

      #appending new scope to scope list
      new_scope_list.append(SCOPES_BY_SERVICE[service][random_idx])

  #choosing a random scope's idx to add:
  random_idx = random.randint(0,len(ALL_SCOPES)-1)

  #ensuring no duplicates are selected:
  while ALL_SCOPES[random_idx] in new_scope_list:
    random_idx = random.randint(0,len(ALL_SCOPES)-1)

  #choosing random bool for offline/online
  bools = [True,False]
  new_bool = random.choice(bools)

  #duplicate validation and formatting the new combo:
  #creating new combo:
  new_scope_combo = (new_scope_list, new_bool, '',
                     'Strategy G: Plausable Cross Scope Combinations With Random Scope Addition')

  #checking if new addition would be original
  #if so, it's added
  if dict_dupe_validation(scope_dict,new_scope_combo):
    all_scope_combinations.append(new_scope_combo)

    #we use dict to validate, so have to add new addition to dict if valid
    scope_dict[f'{new_scope_combo[0]},{new_scope_combo[1]}'] = new_scope_combo

# %%
#Strategy H: Base Scope Combinations With Random Scope Addition
random.seed(RANDOM_SEED)
for scope_combo in base_scope_combos:
  #generating a random scope
  new_scope = random.choice(ALL_SCOPES)
  #ensuring that our new_scope isn't already in the base_scope list
  while new_scope in scope_combo[0]:
    new_scope = random.choice(ALL_SCOPES)

  new_scope_list = copy.deepcopy(scope_combo[0])
  new_scope_list.append(new_scope)

  bools = [True,False]
  new_bool = random.choice(bools)

  #duplicate validation and formatting the new combo:
  #creating new combo:
  new_scope_combo = (new_scope_list, new_bool, '',
                     'Strategy H: Base Scope Combinations With Random Scope Addition')

  #checking if new addition would be original
  #if so, it's added
  if dict_dupe_validation(scope_dict,new_scope_combo):
    all_scope_combinations.append(new_scope_combo)

    #we use dict to validate, so have to add new addition to dict if valid
    scope_dict[f'{new_scope_combo[0]},{new_scope_combo[1]}'] = new_scope_combo
len(all_scope_combinations)
# Out:
# 1277

# %%
#Strategy I: attemping purposful low risk generation

random.seed(RANDOM_SEED)

#creating a list of services that have 3 or less sensitivity
low_sens_services = []
for service, sens in SERVICE_SENSITIVITY.items():
  if sens <= 3:
    low_sens_services.append(service)


#this code is so hideous it hurts to look at but it works (mostly)
#The logic:
# 1:Itterate over every service in low_sens_services. Assign the coresponding
#  scopes in that services to scopes. LOOP ONE

# 2:For each itteration in LOOP ONE, we start LOOP TWO, which also itterates over
#  every service in low_sens_services.

# 3:For each itteration of LOOP TWO we check and see if itt_service is equal to
#. service, the itterating service in LOOP ONE. If it is, we skip this itteration
#. of the loop.

# 4:We proceed with creating LOOP THREE, which itterates over every scope in scopes.
#. we create itt_scopes which is the list of scopes coresponding to the itterating
# service in LOOP TWO.

# 5:Now we create LOOP FOUR, which is a for loop in the range of the length of
# itt_scopes. We then create new_scope_set, which is a set that will contain our
# new scope combination.

# 6: For each itteration of LOOP FOUR, we create LOOP FIVE. Which has the range
# of the current itteration of LOOP FOUR. So if i = 1, LOOP FIVE's range is 1.
# LOOP FOUR:
#.     - takes the len of new_scope_set
#.     - randomly adds a scope to it that is chosen from
#.     - checks and see if the len of new_scope_set increased, if it did not
#.       it tries again until either a new scope has sucessfully been added
#.       or it tries 10 plus times and the overflow condition breaks the attempt
#.       which happens in LOOP 5.5

# 7: a new scope combo is attempted to be created, if its a dupe it isn't added
#.  to all_scope_combinations.

for service in low_sens_services: #LOOP ONE
  scopes = SCOPES_BY_SERVICE[service]

  for itt_service in low_sens_services: #LOOP TWO
    #if the itt_service equals current service we skip as we've made all possib
    #le ones earlier
    if service == itt_service:
      #itterating over every within service scope
      pass

    else:
      #itterates over each scope in scopes
      for scope in scopes: #LOOP THREE
        #accessing list of scopes in new service that is being itterated over
        #earlier in code:
        itt_scopes = SCOPES_BY_SERVICE[itt_service]

        for i in range(len(itt_scopes)): #LOOP FOUR
          new_scope_set = set([scope])

          for j in range(i): #LOOP FIVE
            len_set = len(new_scope_set)
            new_scope_set.add(random.choice(scopes))

            overflow = 0
            while len(new_scope_set) == len_set: #LOOP FIVE.5
              new_scope_set.add(random.choice(scopes))
              overflow += 1
              if overflow > 10:
                print('OVERFLOW')
                break
            if overflow > 10:
              break

          new_scope_list = list(new_scope_set)
          new_scope_combo = (new_scope_list, False, '',
                    'Strategy I:')
          print(new_scope_combo)
          if dict_dupe_validation(scope_dict,new_scope_combo):
            all_scope_combinations.append(new_scope_combo)

            #we use dict to validate, so have to add new addition to dict if valid
            scope_dict[f'{new_scope_combo[0]},{new_scope_combo[1]}'] = new_scope_combo
# Out:
# (['https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'openid'], False, '', 'Strategy I:')
# (['email', 'https://www.googleapis.com/auth/userinfo.email', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['email', 'profile', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['openid'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'openid'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'openid', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['profile'], False, '', 'Strategy I:')
# (['profile', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['profile', 'https://www.googleapis.com/auth/userinfo.email', 'email'], False, '', 'Strategy I:')
# (['email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.profile', 'email'], False, '', 'Strategy I:')
# (['profile', 'https://www.googleapis.com/auth/userinfo.profile', 'email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'profile'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'openid', 'email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'openid', 'profile', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['openid', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'openid', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'openid', 'profile', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['openid'], False, '', 'Strategy I:')
# (['openid', 'email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'openid', 'profile'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'openid', 'profile', 'email'], False, '', 'Strategy I:')
# (['profile'], False, '', 'Strategy I:')
# (['profile', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['profile', 'openid', 'email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.profile', 'profile', 'openid', 'email'], False, '', 'Strategy I:')
# (['email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'https://www.googleapis.com/auth/userinfo.profile', 'email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.profile', 'https://www.googleapis.com/auth/userinfo.email', 'openid', 'email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'profile'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['openid', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['openid'], False, '', 'Strategy I:')
# (['profile', 'openid'], False, '', 'Strategy I:')
# (['profile'], False, '', 'Strategy I:')
# (['profile', 'openid'], False, '', 'Strategy I:')
# (['email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.profile', 'email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'openid'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['openid', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['openid'], False, '', 'Strategy I:')
# (['openid', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['profile'], False, '', 'Strategy I:')
# (['profile', 'openid'], False, '', 'Strategy I:')
# (['email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['email', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['openid'], False, '', 'Strategy I:')
# (['openid', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['profile'], False, '', 'Strategy I:')
# (['profile', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['email'], False, '', 'Strategy I:')
# (['profile', 'email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'profile'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['openid', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['openid'], False, '', 'Strategy I:')
# (['openid', 'email'], False, '', 'Strategy I:')
# (['profile'], False, '', 'Strategy I:')
# (['profile', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['email'], False, '', 'Strategy I:')
# (['openid', 'email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['openid'], False, '', 'Strategy I:')
# (['profile', 'openid'], False, '', 'Strategy I:')
# (['profile'], False, '', 'Strategy I:')
# (['profile', 'openid'], False, '', 'Strategy I:')
# (['email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['email', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['openid'], False, '', 'Strategy I:')
# (['openid', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['profile'], False, '', 'Strategy I:')
# (['profile', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['email'], False, '', 'Strategy I:')
# (['openid', 'email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['email', 'https://www.googleapis.com/auth/userinfo.email', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'openid', 'profile', 'email'], False, '', 'Strategy I:')
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['email', 'https://www.googleapis.com/auth/userinfo.email', 'profile', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'email', 'https://www.googleapis.com/auth/userinfo.profile', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['email', 'https://www.googleapis.com/auth/userinfo.email', 'openid', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'email', 'https://www.googleapis.com/auth/userinfo.profile', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['email', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['email', 'profile', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['email', 'https://www.googleapis.com/auth/userinfo.email', 'openid', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['profile', 'openid', 'email', 'https://www.googleapis.com/auth/userinfo.profile', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'email', 'https://www.googleapis.com/auth/userinfo.profile', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'email', 'https://www.googleapis.com/auth/userinfo.profile', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'email', 'https://www.googleapis.com/auth/userinfo.profile', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'email', 'https://www.googleapis.com/auth/userinfo.profile', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'email', 'https://www.googleapis.com/auth/userinfo.profile', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'email', 'https://www.googleapis.com/auth/userinfo.profile', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'email', 'https://www.googleapis.com/auth/userinfo.profile', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['email', 'https://www.googleapis.com/auth/userinfo.email', 'profile', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'email', 'https://www.googleapis.com/auth/userinfo.profile', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'email', 'https://www.googleapis.com/auth/userinfo.profile', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'email', 'https://www.googleapis.com/auth/userinfo.profile', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'email', 'https://www.googleapis.com/auth/userinfo.profile', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['openid'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'openid'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'openid', 'profile'], False, '', 'Strategy I:')
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.email', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['profile', 'openid', 'email', 'https://www.googleapis.com/auth/userinfo.profile', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'email', 'https://www.googleapis.com/auth/userinfo.profile', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'email', 'https://www.googleapis.com/auth/userinfo.profile', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/userinfo.profile', 'profile', 'openid', 'email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'email', 'https://www.googleapis.com/auth/userinfo.profile', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'email', 'https://www.googleapis.com/auth/userinfo.profile', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['profile'], False, '', 'Strategy I:')
# (['profile', 'openid'], False, '', 'Strategy I:')
# (['profile', 'openid', 'email'], False, '', 'Strategy I:')
# (['email', 'profile', 'https://www.googleapis.com/auth/userinfo.email', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.email', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'email', 'https://www.googleapis.com/auth/userinfo.profile', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'email', 'https://www.googleapis.com/auth/userinfo.profile', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'email', 'https://www.googleapis.com/auth/userinfo.profile', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'email', 'https://www.googleapis.com/auth/userinfo.profile', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'email'], False, '', 'Strategy I:')
# (['profile', 'openid', 'email'], False, '', 'Strategy I:')
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.email', 'email'], False, '', 'Strategy I:')
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['openid', 'https://www.googleapis.com/auth/userinfo.email', 'https://www.googleapis.com/auth/userinfo.profile', 'email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/userinfo.email', 'openid', 'profile', 'email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# OVERFLOW
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'openid'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'profile', 'email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.profile', 'https://www.googleapis.com/auth/userinfo.email', 'openid', 'email'], False, '', 'Strategy I:')
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['openid', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'openid', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['email', 'https://www.googleapis.com/auth/userinfo.email', 'profile', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['profile', 'openid', 'email', 'https://www.googleapis.com/auth/userinfo.profile', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['openid'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'openid'], False, '', 'Strategy I:')
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.email', 'email'], False, '', 'Strategy I:')
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['profile'], False, '', 'Strategy I:')
# (['profile', 'email'], False, '', 'Strategy I:')
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['email', 'profile', 'https://www.googleapis.com/auth/userinfo.email', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['email'], False, '', 'Strategy I:')
# (['openid', 'email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'https://www.googleapis.com/auth/userinfo.profile', 'email'], False, '', 'Strategy I:')
# (['openid', 'https://www.googleapis.com/auth/userinfo.email', 'https://www.googleapis.com/auth/userinfo.profile', 'email'], False, '', 'Strategy I:')
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'profile'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'profile', 'email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.profile', 'https://www.googleapis.com/auth/userinfo.email', 'openid', 'email'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/userinfo.email', 'openid', 'profile', 'email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['email', 'profile', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['email', 'profile', 'https://www.googleapis.com/auth/userinfo.email', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['profile', 'openid', 'email', 'https://www.googleapis.com/auth/userinfo.profile', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['openid'], False, '', 'Strategy I:')
# (['profile', 'openid'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'openid', 'email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'openid', 'profile', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['profile'], False, '', 'Strategy I:')
# (['profile', 'openid'], False, '', 'Strategy I:')
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.email', 'email'], False, '', 'Strategy I:')
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.profile', 'email'], False, '', 'Strategy I:')
# (['profile', 'openid', 'email'], False, '', 'Strategy I:')
# (['openid', 'https://www.googleapis.com/auth/userinfo.email', 'https://www.googleapis.com/auth/userinfo.profile', 'email'], False, '', 'Strategy I:')
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'profile'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['email', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['openid'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'openid'], False, '', 'Strategy I:')
# (['profile'], False, '', 'Strategy I:')
# (['profile', 'openid'], False, '', 'Strategy I:')
# (['email'], False, '', 'Strategy I:')
# (['openid', 'email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'openid', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'openid', 'profile', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['email', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['profile', 'https://www.googleapis.com/auth/userinfo.email', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['email', 'profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# OVERFLOW
# (['email', 'profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['openid'], False, '', 'Strategy I:')
# (['profile', 'openid'], False, '', 'Strategy I:')
# (['email', 'openid', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'openid', 'profile', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['profile'], False, '', 'Strategy I:')
# (['profile', 'email'], False, '', 'Strategy I:')
# (['profile', 'https://www.googleapis.com/auth/userinfo.email', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.email', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['email'], False, '', 'Strategy I:')
# (['profile', 'email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'openid', 'email'], False, '', 'Strategy I:')
# (['openid', 'https://www.googleapis.com/auth/userinfo.email', 'https://www.googleapis.com/auth/userinfo.profile', 'email'], False, '', 'Strategy I:')
# (['profile', 'openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email', 'https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'profile', 'email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'openid', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['openid'], False, '', 'Strategy I:')
# (['openid', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['email', 'openid', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['profile'], False, '', 'Strategy I:')
# (['profile', 'email'], False, '', 'Strategy I:')
# (['profile', 'https://www.googleapis.com/auth/userinfo.email', 'email'], False, '', 'Strategy I:')
# (['email'], False, '', 'Strategy I:')
# (['openid', 'email'], False, '', 'Strategy I:')
# (['openid', 'https://www.googleapis.com/auth/userinfo.profile', 'email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'profile', 'email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['profile', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'profile', 'https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['openid'], False, '', 'Strategy I:')
# (['openid', 'email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email', 'openid', 'email'], False, '', 'Strategy I:')
# (['profile'], False, '', 'Strategy I:')
# (['profile', 'email'], False, '', 'Strategy I:')
# (['profile', 'https://www.googleapis.com/auth/userinfo.profile', 'email'], False, '', 'Strategy I:')
# (['email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.profile', 'email'], False, '', 'Strategy I:')
# (['profile', 'openid', 'email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/userinfo.profile'], False, '', 'Strategy I:')
# (['openid'], False, '', 'Strategy I:')
# (['profile'], False, '', 'Strategy I:')
# (['email'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_write'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_write'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_write'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_write'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_write'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_write'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_write'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_write'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_write'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/devstorage.read_only', 'https://www.googleapis.com/auth/devstorage.read_write', 'https://www.googleapis.com/auth/devstorage.full_control'], False, '', 'Strategy I:')
# OVERFLOW
# ...
# OVERFLOW
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.deployments', 'https://www.googleapis.com/auth/script.projects'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.deployments', 'https://www.googleapis.com/auth/script.projects'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.deployments', 'https://www.googleapis.com/auth/script.projects'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.deployments', 'https://www.googleapis.com/auth/script.projects'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.deployments', 'https://www.googleapis.com/auth/script.projects'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.deployments', 'https://www.googleapis.com/auth/script.projects'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.deployments', 'https://www.googleapis.com/auth/script.projects'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects', 'https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.projects', 'https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.projects', 'https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.projects', 'https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects.readonly'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.deployments', 'https://www.googleapis.com/auth/script.projects'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.deployments', 'https://www.googleapis.com/auth/script.projects'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.projects', 'https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.deployments', 'https://www.googleapis.com/auth/script.projects'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.deployments', 'https://www.googleapis.com/auth/script.projects'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.deployments', 'https://www.googleapis.com/auth/script.projects'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.projects'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.projects', 'https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.projects', 'https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.projects', 'https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects.readonly'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.deployments', 'https://www.googleapis.com/auth/script.projects'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.projects', 'https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.projects', 'https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.deployments', 'https://www.googleapis.com/auth/script.projects'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.deployments', 'https://www.googleapis.com/auth/script.projects'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.deployments', 'https://www.googleapis.com/auth/script.projects'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects', 'https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects.readonly'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.projects'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.deployments', 'https://www.googleapis.com/auth/script.projects'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects', 'https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.projects', 'https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.projects', 'https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.projects', 'https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects.readonly'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.projects', 'https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.projects', 'https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.projects', 'https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.deployments', 'https://www.googleapis.com/auth/script.projects'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.deployments', 'https://www.googleapis.com/auth/script.projects'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.deployments', 'https://www.googleapis.com/auth/script.projects'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects', 'https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.projects', 'https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects.readonly'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.projects'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.deployments', 'https://www.googleapis.com/auth/script.projects'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects.readonly', 'https://www.googleapis.com/auth/script.deployments', 'https://www.googleapis.com/auth/script.projects'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.projects.readonly'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/script.deployments'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')
# OVERFLOW
# (['https://www.googleapis.com/auth/groups'], False, '', 'Strategy I:')

# %%
#Doing one final duplicate check
dupe_list = duplicate_check(all_scope_combinations)
dupe_list
# Out:
# []

# %%
#Adding description strings for every combo that doesn't have one
for idx, scope_combo in enumerate(copy.deepcopy(all_scope_combinations)):
  #use deep copy as we itterating while modifying. I don't think we technically
  #need it here, but safe than sorry.
  #using enumerate to keep track of what item we are on as we are itterating over
  #a copy but will need to modify original

  #skipping itteration of loop if the desc str is present
  if len(scope_combo[2]) > 0:
    continue

  #creating desc string and populating it
  desc_str = ''
  for scope in scope_combo[0]:
    desc_str += f'service: {SCOPE_DB[scope]['service']}, access_type: {SCOPE_DB[scope]['access_type']}, google_classification: {SCOPE_DB[scope]['google_classification']}; '

  #Adding if the combo has a refresh token or not
  if scope_combo[1]:
    desc_str += 'Offline refresh token'
  else:
    desc_str += 'Online access only'

  #creating a list version of the coresponding idx in all_scope_combinations
  new_scope_combo = list(all_scope_combinations[idx])

  #reasinging idx 3
  new_scope_combo[2] = desc_str

  #converting back to tuple and replacing value in all_scope_combinations:
  new_scope_combo = tuple(new_scope_combo)
  all_scope_combinations[idx] = new_scope_combo

# %%
#row construction
rows = [] #will be written to a csv
for idx, scope_combo in enumerate(all_scope_combinations):
  #generating features from our scope_combo
  features = engineer_features(scope_combo[0],scope_combo[1])

  #converting scopes from list to str joined by '; '
  scope_urls = ''
  for scope in scope_combo[0]:
    scope_urls += f'{scope}; '

  #converting online/offline Bool into 0 or 1
  #0 -> online only (False)  1 -> offline access (True)
  if scope_combo[1]:
    include_offline = 1
  else:
    include_offline = 0

  #risk label generation
  points = 0
  #Low = 0-3, Medium = 4-8, High = 9-15, Critical = 16-25(max score)
  #There also is several overides that set a critical floor and a high floor.

  ###Multi-category mapping:

  #data_sensitivity points mapping:
  data_sens_dict = {
      1: 0, #name, photo, email - near publicaly avaible info not risky
      2: 1, #website metrics, ad revenue - not extremly risky
      3: 2, #calendar, tasks, forms - reveals patterns, slighly risky
      4: 4, #files, photos, contacts, health data - risky
      5: 6, #email and admin: very risky
  }
  #determining point addition based on key:
  points += data_sens_dict[features['data_sensitivity']]

  #access level points mapping:
  access_level_dict = {
      0: 0, #read only, view only
      1: 2, #read-write, can modify data and send messages
      2: 4, #full-access, complete control including permenant delation
      3: 6, #control other users accounts, domain-wise compromise
  }
  #determining point addition based on key:
  points += access_level_dict[features['access_level']]

  ###Binary features mapping: we use multipication as its 1 or 0 so if we multipy
  #the zero nothing happens, but if its one, the propper addition occurs

  points += (features['persistence'] * 3) #offline access
  points += (features['transitive_exposure'] * 2) #exposes other users accounts
  points += (features['has_restricted_scope'] * 2) #has google classified restricted scope

  ###Count features mapping:

  #scope count mapping
  if features['scope_count'] >= 6: #broad overrequesting
    points += 3
  elif features['scope_count'] >= 4: #broad request
    points += 2
  elif features['scope_count'] == 3: #moderate request
    points += 1

  #service breadth mapping:
  if features['cross_service_breadth'] >= 4: #very wide
    points += 3
  else: #if less than 4, we just add 1 less than num of services:
    points += features['cross_service_breadth'] - 1

  #mapping points to risk_label:
  if points >= 16:
    risk_label = 'Critical'
  elif points >= 10:
    risk_label = 'High'
  elif points >= 5:
    risk_label = 'Medium'
  else:
    risk_label = 'Low'

  ###overides:

  #critical floor:
  if risk_label == 'Critical':
    pass
  else:
    #admin access with persistence:
    if features['access_level'] == 3 and features['persistence'] == 1:
      risk_label = 'Critical'

    #email/admin full access with broad request:
    elif features['data_sensitivity'] == 5 and features['access_level'] >= 2 and features['scope_count'] >= 3:
      risk_label = 'Critical'

  #high floor:
  if risk_label == 'Critical' or risk_label == 'High':
    pass
  else:
    #persistant email/admin:
    if features['data_sensitivity'] == 5 and features['persistence'] == 1:
      risk_label = 'High'

    #any admin access:
    elif features['access_level'] == 3:
      risk_label = 'High'

    #restricted + persistence + multiservice:
    if features['has_restricted_scope'] == 1 and features['persistence'] == 1 and features['cross_service_breadth'] >= 2:
      risk_label = 'High'

  row = {
      'combination_id' : f"SC-{idx:04}", #:04 wraps in 0s
      'source_category' : scope_combo[3], #where it comes from
      'source_label' : scope_combo[2], #description string
      'scope_urls' : scope_urls, #scopes joined by '; '
      'data_sensitivity': features['data_sensitivity'],
      'persistence': features['persistence'],
      'transitive_exposure': features['transitive_exposure'],
      'scope_count': features['scope_count'],
      'cross_service_breadth': features['cross_service_breadth'],
      'has_restricted_scope': features['has_restricted_scope'],
      'access_level': features['access_level'],
      'risk_label': risk_label
  }
  rows.append(row)

# %%
df = pd.DataFrame(rows)
df_new = df.set_index('combination_id')
df_new
# Out:
#                 source_category  \
# combination_id
# SC-0000         Student Created
# SC-0001         Student Created
# SC-0002         Student Created
# SC-0003         Student Created
# SC-0004         Student Created
# ...                         ...
# SC-1914             Strategy I:
# SC-1915             Strategy I:
# SC-1916             Strategy I:
# SC-1917             Strategy I:
# SC-1918             Strategy I:
#
#                                                      source_label  \
# combination_id
# SC-0000         Offline access to actively monitor fitness act...
# SC-0001         Full online access to YouTube account, includi...
# SC-0002         Authentication, email adress, personalization ...
# SC-0003         Authentication, email adress, personalization ...
# SC-0004         Authentication, email adress, personalization ...
# ...                                                           ...
# SC-1914         service: Apps Script, access_type: write, goog...
# SC-1915         service: Apps Script, access_type: read, googl...
# SC-1916         service: Apps Script, access_type: write, goog...
# SC-1917         service: Apps Script, access_type: write, goog...
# SC-1918         service: Groups, access_type: full_access, goo...
#
#                                                        scope_urls  \
# combination_id
# SC-0000         openid; profile; email; https://www.googleapis...
# SC-0001         openid; profile; email; https://www.googleapis...
# SC-0002         openid; profile; email; https://www.googleapis...
# SC-0003         openid; profile; email; https://www.googleapis...
# SC-0004         openid; profile; email; https://www.googleapis...
# ...                                                           ...
# SC-1914         https://www.googleapis.com/auth/script.deploym...
# SC-1915         https://www.googleapis.com/auth/script.project...
# SC-1916         https://www.googleapis.com/auth/script.deploym...
# SC-1917         https://www.googleapis.com/auth/script.project...
# SC-1918                  https://www.googleapis.com/auth/groups;
#
#                 data_sensitivity  persistence  transitive_exposure  \
# combination_id
# SC-0000                        4            1                    0
# SC-0001                        4            0                    0
# SC-0002                        5            0                    1
# SC-0003                        4            1                    0
# SC-0004                        4            0                    0
# ...                          ...          ...                  ...
# SC-1914                        3            0                    0
# SC-1915                        3            0                    0
# SC-1916                        3            0                    0
# SC-1917                        3            0                    0
# SC-1918                        3            0                    0
#
#                 scope_count  cross_service_breadth  has_restricted_scope  \
# combination_id
# SC-0000                   6                      3                     0
# SC-0001                   5                      3                     0
# SC-0002                   5                      3                     0
# SC-0003                   5                      3                     0
# SC-0004                   4                      2                     0
# ...                     ...                    ...                   ...
# SC-1914                   1                      1                     0
# SC-1915                   2                      1                     0
# SC-1916                   2                      1                     0
# SC-1917                   2                      1                     0
# SC-1918                   1                      1                     0
#
#                 access_level risk_label
# combination_id
# SC-0000                    2   Critical
# SC-0001                    2       High
# SC-0002                    1       High
# SC-0003                    1       High
# SC-0004                    2       High
# ...                      ...        ...
# SC-1914                    1        Low
# SC-1915                    1        Low
# SC-1916                    1        Low
# SC-1917                    1        Low
# SC-1918                    2     Medium
#
# [1919 rows x 11 columns]

# %%
df_new.to_csv('scope_guard_dataset006.csv',index_label='combination_id')

# %%
df_new['risk_label'].value_counts()
# Out:
# risk_label
# Medium      615
# High        566
# Critical    471
# Low         267
# Name: count, dtype: int64

# %%
len(all_scope_combinations)
# Out:
# 1919

# %%
#validating that risk_labeling worked:
random.seed(RANDOM_SEED)

#low validation:
print('LOWS:\n')
past_choices = []
for i in range(10):
  #generating idx of lows to grab
  lows = df_new[df_new['risk_label'] == 'Low']
  rand_idx = random.randint(0,len(lows)-1)

  #ensuring we have no duplicates
  while rand_idx in past_choices:
    rand_idx = random.randint(0,len(lows)-1)
  past_choices.append(rand_idx)

  #grabbing row
  low = lows.iloc[rand_idx]

  #printing out data:
  print(f'URLS: {low['scope_urls']}')
  print(low['data_sensitivity':'risk_label'])
  print('\n\n\n')
  #grabbing coresponding idx in all_scope_combinations

#medium validation:
print('MEDIUMS:\n')
past_choices = []
for i in range(10):
  #generating idx of mediums to grab
  mediums = df_new[df_new['risk_label'] == 'Medium']
  rand_idx = random.randint(0,len(mediums)-1)

  #ensuring we have no duplicates
  while rand_idx in past_choices:
    rand_idx = random.randint(0,len(mediums)-1)
  past_choices.append(rand_idx)

  #grabbing row
  medium = mediums.iloc[rand_idx]

  #printing out data:
  print(f'URLS: {medium['scope_urls']}')
  print(medium['data_sensitivity':'risk_label'])
  print('\n\n\n')
  #grabbing coresponding idx in all_scope_combinations

#high validation:
print('HIGHS:\n')
past_choices = []
for i in range(10):
  #generating idx of highs to grab
  highs = df_new[df_new['risk_label'] == 'High']
  rand_idx = random.randint(0,len(highs)-1)

  #ensuring we have no duplicates
  while rand_idx in past_choices:
    rand_idx = random.randint(0,len(highs)-1)
  past_choices.append(rand_idx)

  #grabbing row
  high = highs.iloc[rand_idx]

  #printing out data:
  print(f'URLS: {high['scope_urls']}')
  print(high['data_sensitivity':'risk_label'])
  print('\n\n\n')
  #grabbing coresponding idx in all_scope_combinations

#critical validation:
print('CRITICALS:\n')
past_choices = []
for i in range(10):
  #generating idx of criticals to grab
  criticals = df_new[df_new['risk_label'] == 'Critical']
  rand_idx = random.randint(0,len(criticals)-1)

  #ensuring we have no duplicates
  while rand_idx in past_choices:
    rand_idx = random.randint(0,len(criticals)-1)
  past_choices.append(rand_idx)

  #grabbing row
  critical = criticals.iloc[rand_idx]

  #printing out data:
  print(f'URLS: {critical['scope_urls']}')
  print(critical['data_sensitivity':'risk_label'])
  print('\n\n\n')
  #grabbing coresponding idx in all_scope_combinations
# Out:
# LOWS:
#
# URLS: email; https://www.googleapis.com/auth/userinfo.profile;
# data_sensitivity           1
# persistence                0
# transitive_exposure        0
# scope_count                2
# cross_service_breadth      1
# has_restricted_scope       0
# access_level               0
# risk_label               Low
# Name: SC-1303, dtype: object
#
#
#
#
# URLS: openid; profile; email; https://www.googleapis.com/auth/adsense.readonly;
# data_sensitivity           2
# persistence                0
# transitive_exposure        0
# scope_count                4
# cross_service_breadth      2
# has_restricted_scope       0
# access_level               0
# risk_label               Low
# Name: SC-0488, dtype: object
#
#
#
#
# URLS: https://www.googleapis.com/auth/calendar.calendarlist.readonly; https://www.googleapis.com/auth/calendar.settings.readonly; https://www.googleapis.com/auth/calendar.acls.readonly;
# data_sensitivity           3
# persistence                0
# transitive_exposure        0
# scope_count                3
# cross_service_breadth      1
# has_restricted_scope       0
# access_level               0
# risk_label               Low
# Name: SC-1486, dtype: object
#
#
#
#
# URLS: https://www.googleapis.com/auth/calendar.acls; https://www.googleapis.com/auth/calendar.calendarlist.readonly;
# data_sensitivity           3
# persistence                0
# transitive_exposure        0
# scope_count                2
# cross_service_breadth      1
# has_restricted_scope       0
# access_level               1
# risk_label               Low
# Name: SC-1451, dtype: object
#
#
#
#
# URLS: https://www.googleapis.com/auth/calendar.calendarlist; https://www.googleapis.com/auth/calendar.events.public.readonly;
# data_sensitivity           3
# persistence                0
# transitive_exposure        0
# scope_count                2
# cross_service_breadth      1
# has_restricted_scope       0
# access_level               1
# risk_label               Low
# Name: SC-1425, dtype: object
#
#
#
#
# URLS: email; openid; https://www.googleapis.com/auth/userinfo.profile;
# data_sensitivity           1
# persistence                0
# transitive_exposure        0
# scope_count                3
# cross_service_breadth      1
# has_restricted_scope       0
# access_level               0
# risk_label               Low
# Name: SC-1317, dtype: object
#
#
#
#
# URLS: https://www.googleapis.com/auth/userinfo.profile; profile; openid; email;
# data_sensitivity           1
# persistence                0
# transitive_exposure        0
# scope_count                4
# cross_service_breadth      1
# has_restricted_scope       0
# access_level               0
# risk_label               Low
# Name: SC-1298, dtype: object
#
#
#
#
# URLS: https://www.googleapis.com/auth/userinfo.email; profile;
# data_sensitivity           1
# persistence                0
# transitive_exposure        0
# scope_count                2
# cross_service_breadth      1
# has_restricted_scope       0
# access_level               0
# risk_label               Low
# Name: SC-1290, dtype: object
#
#
#
#
# URLS: https://www.googleapis.com/auth/calendar.settings.readonly; https://www.googleapis.com/auth/calendar.events;
# data_sensitivity           3
# persistence                0
# transitive_exposure        0
# scope_count                2
# cross_service_breadth      1
# has_restricted_scope       0
# access_level               1
# risk_label               Low
# Name: SC-1657, dtype: object
#
#
#
#
# URLS: profile; email; https://www.googleapis.com/auth/userinfo.email;
# data_sensitivity           1
# persistence                0
# transitive_exposure        0
# scope_count                3
# cross_service_breadth      1
# has_restricted_scope       0
# access_level               0
# risk_label               Low
# Name: SC-0530, dtype: object
#
#
#
#
# MEDIUMS:
#
# URLS: openid; email; profile; https://www.googleapis.com/auth/contacts.readonly;
# data_sensitivity              4
# persistence                   0
# transitive_exposure           1
# scope_count                   4
# cross_service_breadth         2
# has_restricted_scope          0
# access_level                  0
# risk_label               Medium
# Name: SC-0288, dtype: object
#
#
#
#
# URLS: https://www.googleapis.com/auth/user.phonenumbers.read; https://www.googleapis.com/auth/spreadsheets.readonly;
# data_sensitivity              4
# persistence                   0
# transitive_exposure           0
# scope_count                   2
# cross_service_breadth         2
# has_restricted_scope          0
# access_level                  0
# risk_label               Medium
# Name: SC-0720, dtype: object
#
#
#
#
# URLS: https://www.googleapis.com/auth/bigquery.insertdata; https://www.googleapis.com/auth/adsense;
# data_sensitivity              3
# persistence                   0
# transitive_exposure           0
# scope_count                   2
# cross_service_breadth         2
# has_restricted_scope          0
# access_level                  2
# risk_label               Medium
# Name: SC-1166, dtype: object
#
#
#
#
# URLS: https://www.googleapis.com/auth/analytics;
# data_sensitivity              2
# persistence                   0
# transitive_exposure           0
# scope_count                   1
# cross_service_breadth         1
# has_restricted_scope          0
# access_level                  2
# risk_label               Medium
# Name: SC-1327, dtype: object
#
#
#
#
# URLS: https://www.googleapis.com/auth/classroom.coursework.students; https://www.googleapis.com/auth/classroom.rosters;
# data_sensitivity              3
# persistence                   0
# transitive_exposure           1
# scope_count                   2
# cross_service_breadth         1
# has_restricted_scope          0
# access_level                  1
# risk_label               Medium
# Name: SC-1785, dtype: object
#
#
#
#
# URLS: https://www.googleapis.com/auth/calendar.events.readonly; https://www.googleapis.com/auth/tasks.readonly; https://www.googleapis.com/auth/drive.file;
# data_sensitivity              4
# persistence                   0
# transitive_exposure           0
# scope_count                   3
# cross_service_breadth         3
# has_restricted_scope          0
# access_level                  1
# risk_label               Medium
# Name: SC-0234, dtype: object
#
#
#
#
# URLS: https://www.googleapis.com/auth/youtube.readonly; https://www.googleapis.com/auth/youtube.force-ssl; https://www.googleapis.com/auth/youtubepartner;
# data_sensitivity              3
# persistence                   0
# transitive_exposure           0
# scope_count                   3
# cross_service_breadth         1
# has_restricted_scope          0
# access_level                  2
# risk_label               Medium
# Name: SC-1866, dtype: object
#
#
#
#
# URLS: https://www.googleapis.com/auth/script.deployments; https://www.googleapis.com/auth/compute.readonly;
# data_sensitivity              3
# persistence                   1
# transitive_exposure           0
# scope_count                   2
# cross_service_breadth         2
# has_restricted_scope          0
# access_level                  1
# risk_label               Medium
# Name: SC-1128, dtype: object
#
#
#
#
# URLS: https://www.googleapis.com/auth/forms; https://www.googleapis.com/auth/forms.responses.readonly; https://www.googleapis.com/auth/forms.body.readonly;
# data_sensitivity              3
# persistence                   0
# transitive_exposure           0
# scope_count                   3
# cross_service_breadth         1
# has_restricted_scope          0
# access_level                  1
# risk_label               Medium
# Name: SC-1845, dtype: object
#
#
#
#
# URLS: https://www.googleapis.com/auth/calendar.app.created; https://www.googleapis.com/auth/calendar.readonly; https://www.googleapis.com/auth/calendar.freebusy; https://www.googleapis.com/auth/calendar.events.public.readonly; https://www.googleapis.com/auth/calendar.events.readonly;
# data_sensitivity              3
# persistence                   0
# transitive_exposure           0
# scope_count                   5
# cross_service_breadth         1
# has_restricted_scope          0
# access_level                  1
# risk_label               Medium
# Name: SC-1673, dtype: object
#
#
#
#
# HIGHS:
#
# URLS: openid; profile; email; https://www.googleapis.com/auth/fitness.blood_glucose.read;
# data_sensitivity            4
# persistence                 1
# transitive_exposure         0
# scope_count                 4
# cross_service_breadth       2
# has_restricted_scope        0
# access_level                0
# risk_label               High
# Name: SC-0538, dtype: object
#
#
#
#
# URLS: https://www.googleapis.com/auth/chat.delete; https://www.googleapis.com/auth/userinfo.email; email;
# data_sensitivity            4
# persistence                 1
# transitive_exposure         0
# scope_count                 3
# cross_service_breadth       2
# has_restricted_scope        0
# access_level                1
# risk_label               High
# Name: SC-1062, dtype: object
#
#
#
#
# URLS: https://www.googleapis.com/auth/admin.directory.group; https://www.googleapis.com/auth/compute;
# data_sensitivity            5
# persistence                 0
# transitive_exposure         1
# scope_count                 2
# cross_service_breadth       2
# has_restricted_scope        0
# access_level                3
# risk_label               High
# Name: SC-0696, dtype: object
#
#
#
#
# URLS: openid; profile; email; https://www.googleapis.com/auth/chat.messages; https://www.googleapis.com/auth/contacts.readonly;
# data_sensitivity            4
# persistence                 0
# transitive_exposure         1
# scope_count                 5
# cross_service_breadth       3
# has_restricted_scope        0
# access_level                2
# risk_label               High
# Name: SC-0009, dtype: object
#
#
#
#
# URLS: openid; profile; email; https://www.googleapis.com/auth/calendar.events.owned; https://www.googleapis.com/auth/chat.messages.readonly; https://www.googleapis.com/auth/fitness.activity.read;
# data_sensitivity            4
# persistence                 0
# transitive_exposure         0
# scope_count                 6
# cross_service_breadth       4
# has_restricted_scope        0
# access_level                1
# risk_label               High
# Name: SC-0424, dtype: object
#
#
#
#
# URLS: https://www.googleapis.com/auth/user.gender.read; https://www.googleapis.com/auth/chat.messages;
# data_sensitivity            4
# persistence                 1
# transitive_exposure         0
# scope_count                 2
# cross_service_breadth       2
# has_restricted_scope        0
# access_level                2
# risk_label               High
# Name: SC-1029, dtype: object
#
#
#
#
# URLS: https://www.googleapis.com/auth/firebase.messaging; https://www.googleapis.com/auth/analytics.manage.users;
# data_sensitivity            3
# persistence                 0
# transitive_exposure         0
# scope_count                 2
# cross_service_breadth       2
# has_restricted_scope        0
# access_level                3
# risk_label               High
# Name: SC-0826, dtype: object
#
#
#
#
# URLS: openid; profile; email; https://www.googleapis.com/auth/drive.scripts; https://www.googleapis.com/auth/script.projects; https://www.googleapis.com/auth/drive.activity; https://www.googleapis.com/auth/fitness.activity.read;
# data_sensitivity            4
# persistence                 1
# transitive_exposure         0
# scope_count                 7
# cross_service_breadth       4
# has_restricted_scope        0
# access_level                1
# risk_label               High
# Name: SC-0414, dtype: object
#
#
#
#
# URLS: profile; email; https://www.googleapis.com/auth/documents; https://www.googleapis.com/auth/forms.body; https://www.googleapis.com/auth/drive.file;
# data_sensitivity            4
# persistence                 0
# transitive_exposure         0
# scope_count                 5
# cross_service_breadth       4
# has_restricted_scope        0
# access_level                2
# risk_label               High
# Name: SC-0533, dtype: object
#
#
#
#
# URLS: https://www.googleapis.com/auth/script.projects.readonly; https://www.googleapis.com/auth/classroom.rosters;
# data_sensitivity            3
# persistence                 1
# transitive_exposure         1
# scope_count                 2
# cross_service_breadth       2
# has_restricted_scope        0
# access_level                1
# risk_label               High
# Name: SC-0810, dtype: object
#
#
#
#
# CRITICALS:
#
# URLS: openid; profile; email; https://www.googleapis.com/auth/forms.responses.readonly; https://www.googleapis.com/auth/gmail.send;
# data_sensitivity                5
# persistence                     1
# transitive_exposure             0
# scope_count                     5
# cross_service_breadth           3
# has_restricted_scope            1
# access_level                    1
# risk_label               Critical
# Name: SC-0135, dtype: object
#
#
#
#
# URLS: openid; profile; email; https://www.googleapis.com/auth/keep; https://www.googleapis.com/auth/tasks; https://www.googleapis.com/auth/calendar.events.owned;
# data_sensitivity                4
# persistence                     1
# transitive_exposure             0
# scope_count                     6
# cross_service_breadth           4
# has_restricted_scope            1
# access_level                    2
# risk_label               Critical
# Name: SC-0120, dtype: object
#
#
#
#
# URLS: openid; profile; email; https://www.googleapis.com/auth/analytics.readonly; https://www.googleapis.com/auth/spreadsheets; https://www.googleapis.com/auth/calendar.events.readonly;
# data_sensitivity                4
# persistence                     1
# transitive_exposure             0
# scope_count                     6
# cross_service_breadth           4
# has_restricted_scope            0
# access_level                    2
# risk_label               Critical
# Name: SC-0406, dtype: object
#
#
#
#
# URLS: openid; profile; email; https://www.googleapis.com/auth/chat.messages; https://www.googleapis.com/auth/drive.readonly;
# data_sensitivity                4
# persistence                     1
# transitive_exposure             0
# scope_count                     5
# cross_service_breadth           3
# has_restricted_scope            1
# access_level                    2
# risk_label               Critical
# Name: SC-0122, dtype: object
#
#
#
#
# URLS: openid; profile; email; https://www.googleapis.com/auth/firebase; https://www.googleapis.com/auth/fitness.blood_glucose.read; https://www.googleapis.com/auth/gmail.send;
# data_sensitivity                5
# persistence                     1
# transitive_exposure             0
# scope_count                     6
# cross_service_breadth           4
# has_restricted_scope            1
# access_level                    2
# risk_label               Critical
# Name: SC-0388, dtype: object
#
#
#
#
# URLS: openid; profile; email; https://www.googleapis.com/auth/photoslibrary.appendonly; https://www.googleapis.com/auth/chat.messages.readonly; https://www.googleapis.com/auth/gmail.addons.current.message.readonly; https://www.googleapis.com/auth/admin.directory.user;
# data_sensitivity                5
# persistence                     0
# transitive_exposure             1
# scope_count                     7
# cross_service_breadth           5
# has_restricted_scope            0
# access_level                    3
# risk_label               Critical
# Name: SC-1223, dtype: object
#
#
#
#
# URLS: https://www.googleapis.com/auth/devstorage.read_write; https://www.googleapis.com/auth/admin.datatransfer; https://www.googleapis.com/auth/contacts.readonly;
# data_sensitivity                5
# persistence                     1
# transitive_exposure             1
# scope_count                     3
# cross_service_breadth           3
# has_restricted_scope            0
# access_level                    3
# risk_label               Critical
# Name: SC-0367, dtype: object
#
#
#
#
# URLS: https://www.googleapis.com/auth/calendar.calendarlist; https://www.googleapis.com/auth/gmail.insert; https://www.googleapis.com/auth/keep.readonly; https://www.googleapis.com/auth/forms; https://www.googleapis.com/auth/documents.readonly;
# data_sensitivity                5
# persistence                     1
# transitive_exposure             0
# scope_count                     5
# cross_service_breadth           5
# has_restricted_scope            1
# access_level                    1
# risk_label               Critical
# Name: SC-0862, dtype: object
#
#
#
#
# URLS: https://www.googleapis.com/auth/admin.directory.user.readonly; https://www.googleapis.com/auth/admin.reports.audit.readonly; https://www.googleapis.com/auth/chat.messages;
# data_sensitivity                5
# persistence                     0
# transitive_exposure             1
# scope_count                     3
# cross_service_breadth           2
# has_restricted_scope            0
# access_level                    2
# risk_label               Critical
# Name: SC-0295, dtype: object
#
#
#
#
# URLS: openid; profile; email; https://www.googleapis.com/auth/keep; https://www.googleapis.com/auth/tasks; https://www.googleapis.com/auth/calendar.events.owned; https://www.googleapis.com/auth/chat.messages;
# data_sensitivity                4
# persistence                     0
# transitive_exposure             0
# scope_count                     7
# cross_service_breadth           5
# has_restricted_scope            1
# access_level                    2
# risk_label               Critical
# Name: SC-1192, dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Get unique source categories
source_categories = df_new['source_category'].unique()

# Iterate through each source category and create a countplot
for category in source_categories:
    plt.figure(figsize=(10, 6))
    sns.countplot(data=df_new[df_new['source_category'] == category], x='risk_label', order=['Low', 'Medium', 'High', 'Critical'], hue='risk_label', palette='viridis', legend=False)
    plt.title(f'Distribution of Risk Labels for: {category}')
    plt.xlabel('Risk Label')
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# %%
# Get unique source categories
source_categories = df_new['source_category'].unique()

# Iterate through each source category and create a countplot

plt.figure(figsize=(10, 6))
sns.countplot(data=df_new, x='risk_label', order=['Low', 'Medium', 'High', 'Critical'], hue='risk_label', palette='viridis', legend=False)
plt.title(f'Distribution of Risk Labels')
plt.xlabel('Risk Label')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
#exporting randomly gen combos
random_combos = df_new[df_new['source_category'] == 'Strategy F: Randomly Generated Scope Combinations']
random_combos.to_csv('random_combos.csv', index_label='combination_id')
